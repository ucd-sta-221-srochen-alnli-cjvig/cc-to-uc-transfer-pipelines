# %%
import pandas as pd
import time

# %%
from ucd_sta_221_project.api.college_scorecard import (
    get_scorecards_by_state,
    get_latest_student_scorecard_data_by_state,
    get_scorecard_by_college,
)

from ucd_sta_221_project.api.cccco import (
    get_ccc_colleges,
    get_ccc_districts,
    get_ccc_programs
)

# %% [markdown]
# # Exploring the API

# %%
import os
import requests

url = "https://api.data.gov/ed/collegescorecard/v1/schools"

fields = [
    "school.name",
    "2018.student.size",
    "2018.student.enrollment", # You can return all elements within a dict by requesting the top level instead of "2018.student.enrollment.undergrad_12_month",
    # "2018.student.demographics.over_23_at_entry",
    # "2018.student.demographics.first_generation",
    # "2018.student.demographics.median_hh_income",
    # "2018.student.demographics.student_faculty_ratio",
    # "2018.student.FAFSA_applications",
]

params = {
    "api_key": os.getenv("SCORECARDAPI"),
    "school.name": "Solano College",
    # "fields": ",".join(fields)
}

response = requests.get(url, params=params)
print(response.json()["metadata"])
data = response.json()
# Out:
# {'page': 0, 'total': 1, 'per_page': 20}

# %%
data_results = data.get("results")[0]
data_results
# Out:
# {'2018.student.size': 7972,
#  '2018.student.enrollment.all': None,
#  '2018.student.enrollment.undergrad_12_month': 13835,
#  '2018.student.enrollment.grad_12_month': None,
#  'school.name': 'Solano Community College'}

# %%
# data.keys() # dict_keys(['metadata', 'results'])
# len(data.get("results")) # 1 - list of dicts

data_results = data.get("results")[0]
data_results.keys() # dict_keys(['latest', 'school', 'location', 'id', 'ope6_id', 'ope8_id', 'fed_sch_cd'])
# Out:
# dict_keys(['latest', 'school', 'location', 'id', 'ope6_id', 'ope8_id', 'fed_sch_cd'])

# %%
# Drill down into the values of data_results

data_results_latest = data_results.get("latest")
# data_results_latest.keys()
# dict_keys(
#     [
#         'school',
#         'student',
#         'cost',
#         'aid',
#         'earnings',
#         'completion',
#         'repayment',
#         'admissions',
#         'academics',
#         'programs'
#     ]
# )

data_results_school = data_results.get("school")
# data_results_school # School metadata

data_results_location = data_results.get("location")
# data_results_location # Lat-Long dict

data_results_id = data_results.get("id")
# data_results_id # int

data_results_ope6_id = data_results.get("ope6_id")
# data_results_ope6_id # str OPE6 ID

data_results_ope8_id = data_results.get("ope8_id")
# data_results_ope8_id # str OPE8 ID

data_results_fed_sch_cd = data_results.get("fed_sch_cd")
# data_results_fed_sch_cd # str Federal School Code

# %%
# `Results > Latest > School` contains more info than `Results > School`

data_results_latest_school = data_results_latest.get("school")
print(f"{data_results_latest_school.keys() = }")
print(f"{data_results_school.keys()        = }")

# data_results_latest_school.keys() - data_results_school.keys() # {'peps_ownership', 'state_fips'}
# data_results_school.keys() - data_results_latest_school.keys() # set()
# Out:
# data_results_latest_school.keys() = dict_keys(['zip', 'city', 'name', 'alias', 'state', 'locale', 'address', 'dolflag', 'branches', 'men_only', 'operating', 'ownership', 'region_id', 'accreditor', 'school_url', 'state_fips', 'women_only', 'main_campus', 'online_only', 'endowment', 'carnegie_basic', 'faculty_salary', 'ownership_peps', 'peps_ownership', 'accreditor_code', 'ft_faculty_rate', 'sector', 'carnegie_undergrad', 'degree_urbanization', 'under_investigation', 'price_calculator_url', 'carnegie_size_setting', 'minority_serving', 'religious_affiliation', 'open_admissions_policy', 'title_iv', 'degrees_awarded', 'tuition_revenue_per_fte', 'instructional_expenditure_per_fte', 'institutional_characteristics'])
# data_results_school.keys()        = dict_keys(['zip', 'city', 'name', 'alias', 'state', 'locale', 'address', 'dolflag', 'branches', 'men_only', 'operating', 'ownership', 'region_id', 'accreditor', 'school_url', 'women_only', 'main_campus', 'online_only', 'endowment', 'carnegie_basic', 'faculty_salary', 'ownership_peps', 'accreditor_code', 'ft_faculty_rate', 'sector', 'carnegie_undergrad', 'degree_urbanization', 'under_investigation', 'price_calculator_url', 'carnegie_size_setting', 'minority_serving', 'religious_affiliation', 'open_admissions_policy', 'title_iv', 'degrees_awarded', 'tuition_revenue_per_fte', 'instructional_expenditure_per_fte', 'institutional_characteristics'])

# %%
data_results_latest_student = data_results_latest.get("student")
# data_results_latest_student.keys()
# dict_keys(
#     [
#         'size',
#         'grad_students',
#         'size_category',
#         'enrollment',
#         'share_25_older',
#         'part_time_share',
#         'demographics',
#         'FAFSA_applications',
#         'fafsa_sent',
#         'part_time_share_2000',
#         'family_income',
#         'share_firstgeneration',
#         'parents_education_level',
#         'share_lowincome',
#         'valid_dependency_status',
#         'students_with_pell_grant',
#         'share_first',
#         'share_independent_students',
#         'share_highincome',
#         'undergrads_non_degree_seeking',
#         'share_middleincome',
#         'avg_dependent_income',
#         'retention_rate',
#         'avg_independent_income',
#         'share_dependent_lowincome',
#         'share_independent_lowincome',
#         'share_dependent_highincome',
#         'share_independent_highincome',
#         'share_dependent_middleincome',
#         'share_firstgeneration_parents',
#         'share_independent_middleincome',
#         'undergrads_with_pell_grant_or_federal_student_loan',
#         'retention_rate_suppressed',
#         'dcs_undergrads_with_pell_grant_or_federal_student_loan',
#         'ftft_undergrads_with_pell_grant_or_federal_student_loan',
#         'dcs_undergrads_with_pell_grant_or_federal_student_loan_pooled',
#         'ftft_undergrads_with_pell_grant_or_federal_student_loan_pooled'
#     ]
# )

# %%
data_results_latest_cost = data_results_latest.get("cost")
# data_results_latest_cost.keys()
# dict_keys(
#     [
#         'booksupply',
#         'tuition',
#         'roomboard',
#         'title_iv',
#         'avg_net_price',
#         'otherexpense',
#         'attendance',
#         'net_price',
#         'program_reporter'
#     ]
# )

# %%
data_results_latest_aid = data_results_latest.get("aid")
# data_results_latest_aid.keys()
# dict_keys(
#     [
#         'loan_principal',
#         'pell_grant_rate',
#         'federal_loan_rate',
#         'dcs_pell_grant_rate',
#         'plus_loan_pct_lower',
#         'plus_loan_pct_upper',
#         'plus_loan_pct_years',
#         'ftft_pell_grant_rate',
#         'dcs_federal_loan_rate',
#         'cumulative_debt',
#         'ftft_federal_loan_rate',
#         'median_debt',
#         'students_with_any_loan',
#         'portfolio',
#         'dcs_pell_grant_rate_pooled',
#         'plus_loan_pct_lower_pooled',
#         'plus_loan_pct_upper_pooled',
#         'ftft_pell_grant_rate_pooled',
#         'dcs_federal_loan_rate_pooled',
#         'plus_debt',
#         'ftft_federal_loan_rate_pooled',
#         'median_debt_suppressed',
#         'dcs_undergrads_pell_federal_loan_years',
#         'ftft_undergrads_pell_federal_loan_years',
#         'plus_debt_suppressed'
#     ]
# )

# %%
data_results_latest_earnings = data_results_latest.get("earnings")
# data_results_latest_earnings.keys()
# dict_keys(
#     [
#         'student_count',
#         '6_yrs_after_entry',
#         '7_yrs_after_entry',
#         '10_yrs_after_entry',
#         '11_yrs_after_entry',
#         '1_yr_after_completion',
#         '4_yrs_after_completion',
#         '5_yrs_after_completion',
#         '8_yrs_after_entry',
#         '9_yrs_after_entry',
#         '3_yrs_after_completion'
#     ]
# )

# %%
data_results_latest_completion = data_results_latest.get("completion")
# data_results_latest_completion.keys()
# dict_keys(
#     [
#         'consumer_rate',
#         'pooled_yrs_used',
#         'pooled_yrs_used_100',
#         'pooled_yrs_used_200',
#         'title_iv',
#         'separation_date',
#         '2_yr_completion',
#         '3_yr_completion',
#         '4_yr_completion',
#         '6_yr_completion',
#         '8_yr_completion',
#         'rate_suppressed',
#         'pooled_yrs_used_pell_150',
#         'completion_rate_4yr_100nt',
#         'completion_rate_4yr_150nt',
#         'completion_rate_4yr_200nt',
#         'outcome_years',
#         'completion_cohort_4yr_100nt',
#         'completion_cohort_4yr_150nt',
#         'completion_cohort_4yr_200nt',
#         'transfer_rate',
#         'completion_rate_4yr_150_aian',
#         'completion_rate_4yr_150_nhpi',
#         'completion_rate_4yr_150_asian',
#         'completion_rate_4yr_150_black',
#         'completion_rate_4yr_150_white',
#         'completion_rate_l4yr_150_aian',
#         'completion_rate_l4yr_150_nhpi',
#         'outcome_cohort_nopell',
#         'completion_cohort_4yr_150_aian',
#         'completion_cohort_4yr_150_nhpi',
#         'completion_rate_l4yr_150_asian',
#         'completion_rate_l4yr_150_black',
#         'completion_rate_l4yr_150_white',
#         'completion_cohort_4yr_150_asian',
#         'completion_cohort_4yr_150_black',
#         'completion_cohort_4yr_150_white',
#         'completion_rate_4yr_150_2ormore',
#         'outcome_years_pell',
#         'completion_rate_4yr_150_hispanic',
#         'completion_rate_4yr_150nt_pooled',
#         'completion_rate_4yr_200nt_pooled',
#         'completion_rate_l4yr_150_2ormore',
#         'completion_cohort_4yr_150_2ormore',
#         'completion_rate_l4yr_150_hispanic',
#         'completion_cohort_4yr_150_hispanic',
#         'completion_cohort_4yr_150nt_pooled',
#         'completion_cohort_4yr_200nt_pooled',
#         'completion_rate_four_year_150_pell',
#         'completion_rate_4yr_150_api_pre2010',
#         'completion_rate_less_than_4yr_100nt',
#         'completion_rate_less_than_4yr_150nt',
#         'completion_rate_less_than_4yr_200nt',
#         'completion_cohort_four_year_150_pell',
#         'completion_rate_4yr_150_aian_pre2010',
#         'completion_rate_4yr_150_race',
#         'completion_rate_four_year_100_pooled',
#         'completion_rate_l4yr_150_api_pre2010',
#         'completion_cohort_4yr_150_api_pre2010',
#         'completion_cohort_less_than_4yr_100nt',
#         'completion_cohort_less_than_4yr_150nt',
#         'completion_cohort_less_than_4yr_200nt',
#         'completion_rate_4yr_150_black_pre2010',
#         'completion_rate_4yr_150_white_pre2010',
#         'completion_rate_l4yr_150_aian_pre2010',
#         'completion_rate_l4yr_150_race',
#         'completion_rate_lt_four_year_150_pell',
#         'completion_cohort_4yr_150_aian_pre2010',
#         'completion_cohort_4yr_150_race',
#         'completion_cohort_four_year_100_pooled',
#         'completion_rate_l4yr_150_black_pre2010',
#         'completion_rate_l4yr_150_white_pre2010',
#         'outcome_percentage',
#         'completion_cohort_4yr_150_black_pre2010',
#         'completion_cohort_4yr_150_white_pre2010',
#         'completion_cohort_lt_four_year_150_pell',
#         'completion_rate_lt_four_year_100_pooled',
#         'outcome_cohort',
#         'completion_cohort_less_than_4yr_150_aian',
#         'completion_cohort_less_than_4yr_150_nhpi',
#         'completion_rate_4yr_150_hispanic_pre2010',
#         'completion_cohort_less_than_4yr_150_asian',
#         'completion_cohort_less_than_4yr_150_black',
#         'completion_cohort_less_than_4yr_150_white',
#         'completion_cohort_lt_four_year_100_pooled',
#         'completion_rate_4yr_150_nonresident',
#         'completion_rate_four_year_150_loan_nopell',
#         'completion_rate_four_year_150_pell_pooled',
#         'completion_rate_l4yr_150_hispanic_pre2010',
#         'rate_suppressed_pell',
#         'completion_cohort_4yr_150_hispanic_pre2010',
#         'completion_rate_l4yr_150_nonresident',
#         'completion_rate_less_than_4yr_150nt_pooled',
#         'completion_rate_less_than_4yr_200nt_pooled',
#         'completion_cohort_4yr_150_nonresident',
#         'completion_cohort_four_year_150_loan_nopell',
#         'completion_cohort_four_year_150_pell_pooled',
#         'completion_cohort_less_than_4yr_150_2ormore',
#         'completion_rate_four_year_150_noloan_nopell',
#         'outcome_percentage_pell',
#         'completion_cohort_less_than_4yr_150_hispanic',
#         'completion_cohort_less_than_4yr_150nt_pooled',
#         'completion_cohort_less_than_4yr_200nt_pooled',
#         'completion_rate_lt_four_year_150_loan_nopell',
#         'completion_rate_lt_four_year_150_pell_pooled',
#         'outcome_cohort_pell',
#         'completion_cohort_four_year_150_noloan_nopell',
#         'transfer_rate_suppressed',
#         'completion_cohort_lt_four_year_150_loan_nopell',
#         'completion_cohort_lt_four_year_150_pell_pooled',
#         'completion_rate_lt_four_year_150_noloan_nopell',
#         'outcome_percentage_nopell',
#         'completion_cohort_less_than_4yr_150_api_pre2010',
#         'completion_cohort_less_than_4yr_150_aian_pre2010',
#         'completion_cohort_less_than_4yr_150_race',
#         'completion_cohort_lt_four_year_150_noloan_nopell',
#         'completion_cohort_less_than_4yr_150_black_pre2010',
#         'completion_cohort_less_than_4yr_150_white_pre2010',
#         'completion_cohort_less_than_4yr_150_hispanic_pre2010',
#         'completion_cohort_less_than_4yr_150_nonresident',
#         'outcome_percentage_suppressed',
#         'outcome_percentage_pell_suppressed'
#     ]
# )

# %%
data_results_latest_repayment = data_results_latest.get("repayment")
# data_results_latest_repayment.keys()
# dict_keys(
#     [
#         '2_yr_default_rate',
#         '3_yr_default_rate',
#         'repayment_date',
#         '1_yr_repayment',
#         '3_yr_repayment',
#         '5_yr_repayment',
#         '7_yr_repayment',
#         '2_yr_default_rate_denom',
#         '3_yr_default_rate_denom',
#         '1_yr_db_pp_repayment',
#         '4_yr_db_pp_repayment',
#         '5_yr_db_pp_repayment',
#         '10_yr_db_pp_repayment',
#         '1_yr_bb_pp_repayment',
#         '1_yr_db_fed_repayment',
#         '20_yr_db_pp_repayment',
#         '2_yr_bb_pp_repayment',
#         '3_yr_bb_pp_repayment',
#         '4_yr_bb_pp_repayment',
#         '4_yr_db_fed_repayment',
#         '5_yr_db_fed_repayment',
#         '10_yr_db_fed_repayment',
#         '1_yr_bb_fed_repayment',
#         '20_yr_db_fed_repayment',
#         '2_yr_bb_fed_repayment',
#         '3_yr_bb_fed_repayment',
#         '4_yr_bb_fed_repayment',
#         '3_yr_repayment_suppressed',
#         '2_yr_bb_fed_repayment_suppressed',
#         'repayment_cohort'
#     ]
# )

# %%
data_results_latest_admissions = data_results_latest.get("admissions")
# data_results_latest_admissions.keys()
# dict_keys(
#     [
#         'test_requirements',
#         'admission_rate', # Has key `'by_ope_id'`. Can we see rate by transfer institution?
#         'act_scores',
#         'sat_scores',
#         'admission_rate_suppressed'
#     ]
# )

# %%
data_results_latest_academics = data_results_latest.get("academics")
# data_results_latest_academics.keys()
# dict_keys(
#     [
#         'program',
#         'program_available',
#         'program_percentage', # Shows distribution of programs (use for %STEM)
#         'program_reporter'
#     ]
# )

# %%
data_results_latest_programs = data_results_latest.get("programs")
# len(data_results_latest_programs.get("cip_4_digit")) # 102

programs = data_results_latest_programs.get("cip_4_digit")

df_programs = pd.DataFrame(
    [
        (
            p.get("code"),
            p.get("title"),
            p.get("ope6_id"),
            p.get("credential").get("title"),
        )
        for p in programs
    ],
    columns=["cip_code", "title", "ope6_id", "credential"],
)

df_programs
# Out:
#     cip_code                                              title ope6_id  \
# 0       0106  Applied Horticulture and Horticultural Busines...  001292
# 1       0106  Applied Horticulture and Horticultural Busines...  001292
# 2       0502  Ethnic, Cultural Minority, Gender, and Group S...  001292
# 3       0901                   Communication and Media Studies.  001292
# 4       0904                                        Journalism.  001292
# ..       ...                                                ...     ...
# 97      5217                                         Insurance.  001292
# 98      5217                                         Insurance.  001292
# 99      5218  General Sales, Merchandising and Related Marke...  001292
# 100     5218  General Sales, Merchandising and Related Marke...  001292
# 101     5401                                           History.  001292
#
#                                credential
# 0    Undergraduate Certificate or Diploma
# 1                      Associate's Degree
# 2                      Associate's Degree
# 3                      Associate's Degree
# 4                      Associate's Degree
# ..                                    ...
# 97   Undergraduate Certificate or Diploma
# 98                     Associate's Degree
# 99   Undergraduate Certificate or Diploma
# 100                    Associate's Degree
# 101                    Associate's Degree
#
# [102 rows x 4 columns]

# %% [markdown]
# # Attempting to Gather Relevant Data

# %%
import os
import requests

url = "https://api.data.gov/ed/collegescorecard/v1/schools"

fields = [
    "school.name",
    "2018.admissions",
]

## From {year}.aid
# '{year}.aid.ftft_pell_grant_rate',
# '{year}.aid.ftft_federal_loan_rate',
# '{year}.aid.pell_grant_rate',
# '{year}.aid.federal_loan_rate',
# '{year}.aid.loan_principal',
# '{year}.aid.median_debt.income',
# '{year}.aid.median_debt.pell_grant',
# '{year}.aid.median_debt.no_pell_grant',
# '{year}.aid.median_debt.first_generation_students',
# '{year}.aid.median_debt.non_first_generation_students',

## From {year}.student.demographics
# "{year}.student.demographics.race_ethnicity.white",
# "{year}.student.demographics.race_ethnicity.black",
# "{year}.student.demographics.race_ethnicity.hispanic",
# "{year}.student.demographics.race_ethnicity.asian",
# "{year}.student.demographics.race_ethnicity.aian",
# "{year}.student.demographics.race_ethnicity.nhpi",
# "{year}.student.demographics.race_ethnicity.two_or_more",
# "{year}.student.demographics.race_ethnicity.non_resident_alien",
# "{year}.student.demographics.race_ethnicity.unknown",
# "{year}.student.demographics.men",
# "{year}.student.demographics.women",
# "{year}.student.demographics.student_faculty_ratio",
# "{year}.student.demographics.faculty.race_ethnicity.two_or_more",
# "{year}.student.demographics.faculty.race_ethnicity.aian",
# "{year}.student.demographics.faculty.race_ethnicity.asian",
# "{year}.student.demographics.faculty.race_ethnicity.black",
# "{year}.student.demographics.faculty.race_ethnicity.hispanic",
# "{year}.student.demographics.faculty.race_ethnicity.nhpi",
# "{year}.student.demographics.faculty.race_ethnicity.non_resident_alien",
# "{year}.student.demographics.faculty.race_ethnicity.unknown",
# "{year}.student.demographics.faculty.race_ethnicity.white",
# "{year}.student.demographics.faculty.men",
# "{year}.student.demographics.faculty.women",

## From {year}.student.enrollment
# "{year}.student.enrollment.undergrad_12_month",

## From {year}.cost
# '{year}.cost.avg_net_price.public',
# '{year}.cost.net_price.public.by_income_level.0-30000',
# '{year}.cost.net_price.public.by_income_level.30001-48000',
# '{year}.cost.net_price.public.by_income_level.48001-75000',
# '{year}.cost.net_price.public.by_income_level.75001-110000',
# '{year}.cost.net_price.public.by_income_level.110001-plus',
# '{year}.cost.title_iv.public.by_income_level.0-30000',
# '{year}.cost.title_iv.public.by_income_level.30001-48000',
# '{year}.cost.title_iv.public.by_income_level.48001-75000',
# '{year}.cost.title_iv.public.by_income_level.75001-110000',
# '{year}.cost.title_iv.public.by_income_level.110001-plus',
# '{year}.cost.attendance.academic_year',
# '{year}.cost.tuition.in_state',
# '{year}.cost.tuition.out_of_state',
# '{year}.cost.booksupply',
# '{year}.cost.roomboard.oncampus',
# '{year}.cost.otherexpense.oncampus',
# '{year}.cost.roomboard.offcampus',
# '{year}.cost.otherexpense.offcampus',
# '{year}.cost.otherexpense.withfamily',

## From {year}.academics
# '{year}.academics.program_percentage', # Shows distribution of programs (use for %STEM)

## From {year}.admissions
# '{year}.admissions.admission_rate.overall'

params = {
    "api_key": os.getenv("SCORECARDAPI"),
    "school.name": "University of California Davis",
    "fields": ",".join(fields)
}

response = requests.get(url, params=params)
print(response.json()["metadata"])
data = response.json()
# Out:
# {'page': 0, 'total': 1, 'per_page': 20}

# %%
data_results = data.get("results")[0]
data_results
# Out:
# {'2018.admissions.admission_rate.overall': 0.4107,
#  '2018.admissions.admission_rate.by_ope_id': 0.4107,
#  '2018.admissions.sat_scores.25th_percentile.critical_reading': 580,
#  '2018.admissions.sat_scores.75th_percentile.critical_reading': 670,
#  '2018.admissions.sat_scores.25th_percentile.math': 580,
#  '2018.admissions.sat_scores.75th_percentile.math': 730,
#  '2018.admissions.sat_scores.25th_percentile.writing': None,
#  '2018.admissions.sat_scores.75th_percentile.writing': None,
#  '2018.admissions.sat_scores.midpoint.critical_reading': 625,
#  '2018.admissions.sat_scores.midpoint.math': 655,
#  '2018.admissions.sat_scores.midpoint.writing': None,
#  '2018.admissions.act_scores.25th_percentile.cumulative': 24,
#  '2018.admissions.act_scores.75th_percentile.cumulative': 32,
#  '2018.admissions.act_scores.25th_percentile.english': 23,
#  '2018.admissions.act_scores.75th_percentile.english': 32,
#  '2018.admissions.act_scores.25th_percentile.math': 23,
#  '2018.admissions.act_scores.75th_percentile.math': 30,
#  '2018.admissions.act_scores.25th_percentile.writing': None,
#  '2018.admissions.act_scores.75th_percentile.writing': None,
#  '2018.admissions.act_scores.midpoint.cumulative': 28,
#  '2018.admissions.act_scores.midpoint.english': 28,
#  '2018.admissions.act_scores.midpoint.math': 27,
#  '2018.admissions.act_scores.midpoint.writing': None,
#  '2018.admissions.sat_scores.average.overall': 1292,
#  '2018.admissions.sat_scores.average.by_ope_id': 1292,
#  '2018.admissions.test_requirements': 1,
#  '2018.admissions.admission_rate_suppressed.overall': None,
#  '2018.admissions.sat_scores.50th_percentile.critical_reading': None,
#  '2018.admissions.sat_scores.50th_percentile.math': None,
#  '2018.admissions.act_scores.50th_percentile.cumulative': None,
#  '2018.admissions.act_scores.50th_percentile.english': None,
#  '2018.admissions.act_scores.50th_percentile.math': None,
#  '2018.admissions.admission_rate.consumer_rate': 0.4107,
#  'school.name': 'University of California-Davis'}

# %%
url = "https://api.data.gov/ed/collegescorecard/v1/schools"

fields = [
    "school.name",
    "ope6_id",
    "ope8_id",
    "fed_sch_cd"
]

params = {
    "api_key": os.getenv("SCORECARDAPI"),
    "ope6_id": ",".join(
        [
            # The 10 UC's:
            "001313",
            "001312",
            "001314",
            "001321",
            "001320",
            "041271",
            "001315",
            "001316",
            "001317",
            "001319",
        ]
    ),
    "fields": ",".join(fields),
    "per_page": 100,
}

response = requests.get(url, params=params)
print(response.json()["metadata"])
data = response.json()
# Out:
# {'page': 0, 'total': 10, 'per_page': 100}

# %%
# For CC's, passing the name to the API is not enough, since it uses fuzzy matching.
# Passing the OPE-ID would be best, but there is no reliable public source for these
# that disaggregates by California Community College. The CCCCO API gives college
# names and locations, so we can use those, with distance set to 1 mile.

# Get the CCC list:
cc_colleges_df = get_ccc_colleges()
cc_colleges_df
# Out:
#     CollegeID                    CollegeName DistrictID  \
# 0         021               Cuyamaca College        020
# 1         022              Grossmont College        020
# 2         031        Imperial Valley College        030
# 3         051              MiraCosta College        050
# 4         061                Palomar College        060
# ..        ...                            ...        ...
# 110       963                  Norco College        960
# 111       971        Copper Mountain College        970
# 112       981          Crafton Hills College        980
# 113       982  San Bernardino Valley College        980
# 114       991          Victor Valley College        990
#
#                     StreetAddress            City          County    Zip  \
# 0    900 Rancho San Diego Parkway        El Cajon       San Diego  92019
# 1    8800 Grossmont College Drive        El Cajon       San Diego  92020
# 2              380 East Aten Road        Imperial        Imperial  92251
# 3                 1 Barnard Drive       Oceanside       San Diego  92056
# 4          1140 West Mission Road      San Marcos       San Diego  92069
# ..                            ...             ...             ...    ...
# 110             2001 Third Street           Norco       Riverside  92860
# 111               6162 Rotary Way     Joshua Tree  San Bernardino  92252
# 112        11711 Sand Canyon Road         Yucaipa  San Bernardino  92399
# 113      701 S. Mt. Vernon Avenue  San Bernardino  San Bernardino  92410
# 114        18422 Bear Valley Road     Victorville  San Bernardino  92392
#
#     ZipPlus4                MailingAddress     MailingCity MailingZip  \
# 0       4304  900 Rancho San Diego Parkway        El Cajon      92019
# 1       1799  8800 Grossmont College Drive        El Cajon      92020
# 2       9787            380 East Aten Road        Imperial      92251
# 3       3899               1 Barnard Drive       Oceanside      92056
# 4       1487        1140 West Mission Road      San Marcos      92069
# ..       ...                           ...             ...        ...
# 110     2600             2001 Third Street           Norco      92860
# 111     6100               6162 Rotary Way     Joshua Tree      92252
# 112     1799        11711 Sand Canyon Road         Yucaipa      92399
# 113     2798      701 S. Mt. Vernon Avenue  San Bernardino      92410
# 114     5849        18422 Bear Valley Road     Victorville      92392
#
#             Phone             WebsiteURL   Latitude   Longitude  \
# 0    619.660.4000       www.cuyamaca.edu  32.744890 -116.935229
# 1    619.644.7000      www.grossmont.edu  32.817897 -117.005640
# 2    760.352.8320       www.imperial.edu  32.825859 -115.502999
# 3    760.757.2121      www.miracosta.edu  33.188864 -117.301064
# 4    760.744.1150        www.palomar.edu  33.147015 -117.183980
# ..            ...                    ...        ...         ...
# 110  951.372.7000   www.norcocollege.edu  33.915421 -117.568755
# 111  760.366.3791          www.cmccd.edu  34.141518 -116.212214
# 112  909.794.2161   www.craftonhills.edu  34.041104 -117.107133
# 113  909.384.4400  www.valleycollege.edu  34.088099 -117.313704
# 114  760.245.4271            www.vvc.edu  34.471081 -117.260293
#
#                                LogoURL District
# 0              CuyamacaCollegeLogo.jpg     None
# 1             GrossmontCollegelogo.jpg     None
# 2    ImperialValleyCollegeLogocopy.jpg     None
# 3       Mira_Costa_College_Logo_4c.png     None
# 4               PalomarCollegeLogo.jpg     None
# ..                                 ...      ...
# 110               NorcoCollegeLogo.jpg     None
# 111            CopperMtCollegelogo.jpg     None
# 112         CraftonHillCollegeLogo.jpg     None
# 113              SanBernardinologo.jpg     None
# 114               VictorValleylogo.jpg     None
#
# [115 rows x 17 columns]

# %%
def fetch_college_data(
        college_name: str,
        latitude: str | None = None,
        longitude: str | None = None,
        distance: int | None = None,
        fields = fields
    ):

    params = {
        "api_key": os.getenv("SCORECARDAPI"),
        "school.name": college_name,
        "school.state": "CA",
        "distance": distance,
        "fields": ",".join(fields),
        "per_page": 10,
    }

    if latitude:
        params["location.lat"] = latitude
    if longitude:
        params["location.lon"] = longitude
    if distance:
        params["distance"] = distance

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        results_list = data.get("results", [])
        results_df = pd.json_normalize(results_list, sep='.')
        return results_df
    except Exception as e:
        print(f"* Error processing {college_name}: {e}")
        return pd.DataFrame()

# %%
url = "https://api.data.gov/ed/collegescorecard/v1/schools"

fields = [
    "school.name",
    "ope6_id",
    "ope8_id",
    "fed_sch_cd"
]

cc_scorecard = pd.DataFrame()

for index, row in cc_colleges_df.iterrows():
    time.sleep(0.5)
    print(f"Processing {row['CollegeName']}...")
    college_data = fetch_college_data(
        college_name=row["CollegeName"],
        latitude=row["Latitude"],
        longitude=row["Longitude"],
        distance=1,
    )
    cc_scorecard = pd.concat([cc_scorecard, college_data], ignore_index=True)

    # There are two colleges (Cerritos College and Palo Verde College)
    # that return no results when lat/lon is provided. They both return unique
    # results when queried without lat/lon and distance.
    if college_data.empty:
        time.sleep(0.5)
        print(f"* College not found. Broadening search...")
        college_data = fetch_college_data(
            college_name=row["CollegeName"],
        )
        cc_scorecard = pd.concat(
            [
                cc_scorecard,
                college_data
            ], ignore_index=True
        )
# Out:
# Processing Cuyamaca College...
# Processing Grossmont College...
# Processing Imperial Valley College...
# Processing MiraCosta College...
# Processing Palomar College...
# Processing San Diego City College...
# Processing San Diego Mesa College...
# Processing San Diego Miramar College...
# Processing Southwestern College...
# Processing Butte College...
# Processing Feather River College...
# Processing Lassen Community College...
# Processing Mendocino College...
# Processing College of the Redwoods...
# Processing Shasta College...
# Processing College of the Siskiyous...
# Processing Lake Tahoe Community College...
# Processing American River College...
# Processing Cosumnes River College...
# Processing Sacramento City College...
# Processing Folsom Lake College...
# Processing Napa Valley College...
# Processing Santa Rosa Junior College...
# Processing Sierra College...
# Processing Solano Community College...
# Processing Yuba College...
# Processing Woodland Community College...
# Processing Contra Costa College...
# Processing Diablo Valley College...
# Processing Los Medanos College...
# Processing College of Marin...
# Processing College of Alameda...
# Processing Laney College...
# Processing Merritt College...
# Processing Berkeley City College...
# Processing City College of San Francisco...
# Processing Cañada College...
# Processing College of San Mateo...
# Processing Skyline College...
# Processing Cabrillo College...
# Processing De Anza College...
# Processing Foothill College...
# Processing Ohlone College...
# Processing Gavilan College...
# Processing Hartnell College...
# Processing Monterey Peninsula College...
# Processing Evergreen Valley College...
# Processing San José City College...
# Processing Las Positas College...
# Processing Chabot College...
# Processing Mission College...
# Processing West Valley College...
# Processing Bakersfield College...
# Processing Cerro Coso Community College...
# Processing Porterville College...
# Processing Merced College...
# Processing San Joaquin Delta College...
# Processing College of the Sequoias...
# Processing Fresno City College...
# Processing Reedley College...
# Processing Madera Community College...
# Processing Clovis Community College...
# Processing Coalinga College...
# Processing Lemoore College...
# Processing Columbia College...
# Processing Modesto Junior College...
# Processing Allan Hancock College...
# Processing Antelope Valley College...
# Processing Cuesta College...
# Processing Santa Barbara City College...
# Processing College of the Canyons...
# Processing Moorpark College...
# Processing Oxnard College...
# Processing Ventura College...
# Processing Taft College...
# Processing Compton College...
# Processing El Camino College...
# Processing Glendale Community College...
# Processing Los Angeles City College...
# Processing Los Angeles Harbor College...
# Processing Los Angeles Mission College...
# Processing Los Angeles Pierce College...
# Processing Los Angeles Southwest College...
# Processing Los Angeles Trade-Technical College...
# Processing Los Angeles Valley College...
# Processing East Los Angeles College...
# Processing West Los Angeles College...
# Processing Pasadena City College...
# Processing Santa Monica College...
# Processing Cerritos College...
# * College not found. Broadening search...
# Processing Citrus College...
# Processing Coastline College...
# Processing Golden West College...
# Processing Orange Coast College...
# Processing Long Beach City College...
# Processing Mt. San Antonio College...
# Processing Cypress College...
# Processing Fullerton College...
# Processing Santa Ana College...
# Processing Santiago Canyon College...
# Processing Rio Hondo College...
# Processing Saddleback College...
# Processing Irvine Valley College...
# Processing Barstow Community College...
# Processing Chaffey College...
# Processing College of the Desert...
# Processing Mt. San Jacinto College...
# Processing Palo Verde College...
# * College not found. Broadening search...
# Processing Riverside City College...
# Processing Moreno Valley College...
# Processing Norco College...
# Processing Copper Mountain College...
# Processing Crafton Hills College...
# Processing San Bernardino Valley College...
# Processing Victor Valley College...

# %%
cc_scorecard.tail(30)
# Out:
#                                    school.name ope6_id   ope8_id fed_sch_cd
# 87                       Pasadena City College  001261  00126100     001261
# 88                        Santa Monica College  001286  00128600     001286
# 89                            Cerritos College  001161  00116100     001161
# 90                              Citrus College  001166  00116600     001166
# 91                 Coastline Community College  020635  02063500     013536
# 92                    Coastline Beauty College  040923  04092300     040923
# 93                         Golden West College  001206  00120600     001206
# 94                        Orange Coast College  001250  00125000     001250
# 95                     Long Beach City College  001219  00121900     001219
# 96                      Mt San Antonio College  001245  00124500     001245
# 97                             Cypress College  001193  00119300     001193
# 98                           Fullerton College  001201  00120100     001201
# 99                    Santa Ana Beauty College  041908  04190800     041908
# 100                          Santa Ana College  001284  00128400     001284
# 101                    Santiago Canyon College  036957  03695700     036957
# 102                          Rio Hondo College  001269  00126900     001269
# 103                         Saddleback College  008918  00891800     008918
# 104                      Irvine Valley College  025395  02539500     025395
# 105                  Barstow Community College  001119  00111900     001119
# 106                            Chaffey College  001163  00116300     001163
# 107                      College of the Desert  001182  00118200     001182
# 108  Mt San Jacinto Community College District  001246  00124600     001246
# 109                         Palo Verde College  001259  00125900     001259
# 110                     Riverside City College  001270  00127000     001270
# 111                      Moreno Valley College  041735  04173500     041735
# 112                              Norco College  041761  04176100     041761
# 113          Copper Mountain Community College  035424  03542400     035424
# 114                      Crafton Hills College  009272  00927200     009272
# 115              San Bernardino Valley College  001272  00127200     001272
# 116                      Victor Valley College  001335  00133500     001335

# %% [markdown]
# # Explore the Code

# %%
alldata = get_scorecards_by_state()
# Out:
# {'page': 1, 'total': 672, 'per_page': 100}
# {'page': 2, 'total': 672, 'per_page': 100}
# {'page': 3, 'total': 672, 'per_page': 100}
# {'page': 4, 'total': 672, 'per_page': 100}
# {'page': 5, 'total': 672, 'per_page': 100}
# {'page': 6, 'total': 672, 'per_page': 100}
# {'page': 7, 'total': 672, 'per_page': 100}

# %%
college1 = alldata[176]
college1.get("school").get("name")
# Out:
# 'Solano Community College'

# %%
college1.keys()
# Out:
# dict_keys(['latest', 'school', 'location', 'id', 'ope6_id', 'ope8_id', 'fed_sch_cd'])

# %%
latest: dict = college1.get("latest")
latest.keys()
# Out:
# dict_keys(['school', 'student', 'cost', 'aid', 'earnings', 'completion', 'repayment', 'admissions', 'academics', 'programs'])

# %%
latest.get("school")
# Out:
# {'zip': '94534-3197',
#  'city': 'Fairfield',
#  'name': 'Solano Community College',
#  'alias': 'Solano College',
#  'state': 'CA',
#  'locale': 22,
#  'address': '4000 Suisun Valley Rd',
#  'dolflag': 1,
#  'branches': 1,
#  'men_only': 0,
#  'operating': 1,
#  'ownership': 1,
#  'region_id': 8,
#  'accreditor': 'Western Association of Schools and Colleges Accrediting Commission for Community and Junior Colleges',
#  'school_url': 'welcome.solano.edu/',
#  'state_fips': 6,
#  'women_only': 0,
#  'main_campus': 1,
#  'online_only': 0,
#  'endowment': {'end': None, 'begin': None},
#  'carnegie_basic': 14,
#  'faculty_salary': 11108,
#  'ownership_peps': 1,
#  'peps_ownership': 'Public',
#  'accreditor_code': 'WASCJC',
#  'ft_faculty_rate': 0.4,
#  'sector': {'scorecard': 7},
#  'carnegie_undergrad': 5,
#  'degree_urbanization': None,
#  'under_investigation': 0,
#  'price_calculator_url': 'https://misweb.cccco.edu/npc/281/npcalc.htm',
#  'carnegie_size_setting': 12,
#  'minority_serving': {'annh': 0,
#   'nant': 0,
#   'aanipi': 1,
#   'tribal': 0,
#   'hispanic': 1,
#   'historically_black': 0,
#   'predominantly_black': 0},
#  'religious_affiliation': None,
#  'open_admissions_policy': 1,
#  'title_iv': {'approval_date': '5/1/1967', 'eligibility_type': 1},
#  'degrees_awarded': {'highest': 3, 'predominant': 2, 'predominant_recoded': 2},
#  'tuition_revenue_per_fte': 946,
#  'instructional_expenditure_per_fte': 9615,
#  'institutional_characteristics': {'level': 1}}

# %%
latest.get("completion")
# Out:
# {'consumer_rate': 0.25,
#  'pooled_yrs_used': 2,
#  'pooled_yrs_used_100': None,
#  'pooled_yrs_used_200': None,
#  'title_iv': {'died_by': {'2yrs': None,
#    '3yrs': None,
#    '4yrs': None,
#    '6yrs': None,
#    '8yrs': None},
#   'unknown_by': {'2yrs': None,
#    '3yrs': 0.01220657277,
#    '4yrs': 0.008986928105,
#    '6yrs': 0.007589025102,
#    '8yrs': 0.219217491369},
#   'completed_by': {'2yrs': 0.046560846561,
#    '3yrs': 0.063849765258,
#    '4yrs': 0.047385620915,
#    '6yrs': 0.065966141273,
#    '8yrs': 0.052934407365},
#   'male': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.29003021148},
#    'completed_by': {'2yrs': 0.045180722892,
#     '3yrs': 0.058823529412,
#     '4yrs': 0.029213483146,
#     '6yrs': 0.045662100457,
#     '8yrs': 0.030211480363},
#    'withdrawn_by': {'2yrs': 0.539156626506,
#     '3yrs': 0.510695187166,
#     '4yrs': 0.519101123596,
#     '6yrs': 0.529680365297,
#     '8yrs': 0.2416918429},
#    'still_enrolled_by': {'2yrs': 0.186746987952,
#     '3yrs': 0.058823529412,
#     '4yrs': 0.047191011236,
#     '6yrs': 0.018264840183,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': 0.030120481928,
#     '3yrs': 0.048128342246,
#     '4yrs': 0.044943820225,
#     '6yrs': 0.036529680365,
#     '8yrs': 0.040785498489},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': 0.032085561497,
#     '4yrs': 0.067415730337,
#     '6yrs': 0.068493150685,
#     '8yrs': 0.117824773414},
#    'transf_withdrawn_2yr_by': {'2yrs': 0.069277108434,
#     '3yrs': 0.082887700535,
#     '4yrs': 0.107865168539,
#     '6yrs': 0.168949771689,
#     '8yrs': 0.166163141994},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': 0.050802139037,
#     '4yrs': 0.049438202247,
#     '6yrs': 0.056316590563,
#     '8yrs': 0.049848942598},
#    'transf_still_enrolled_2yr_by': {'2yrs': 0.045180722892,
#     '3yrs': 0.034759358289,
#     '4yrs': None,
#     '6yrs': 0.021308980213,
#     '8yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': 0.039156626506,
#     '3yrs': 0.096256684492,
#     '4yrs': 0.094382022472,
#     '6yrs': 0.039573820396,
#     '8yrs': 0.016616314199}},
#   'withdrawn_by': {'2yrs': 0.474074074074,
#    '3yrs': 0.442253521127,
#    '4yrs': 0.453431372549,
#    '6yrs': 0.43490951547,
#    '8yrs': 0.231300345224},
#   'depend': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.222081218274},
#    'completed_by': {'2yrs': 0.058690744921,
#     '3yrs': 0.060728744939,
#     '4yrs': 0.057793345009,
#     '6yrs': 0.077247191011,
#     '8yrs': 0.058375634518},
#    'withdrawn_by': {'2yrs': 0.453724604966,
#     '3yrs': 0.425101214575,
#     '4yrs': 0.406304728546,
#     '6yrs': 0.379213483146,
#     '8yrs': 0.175126903553},
#    'still_enrolled_by': {'2yrs': 0.225733634312,
#     '3yrs': 0.109311740891,
#     '4yrs': 0.068301225919,
#     '6yrs': 0.026685393258,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.017766497462},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': 0.022573363431,
#     '3yrs': 0.046558704453,
#     '4yrs': 0.059544658494,
#     '6yrs': 0.077247191011,
#     '8yrs': 0.093908629442},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': 0.036437246964,
#     '4yrs': 0.077057793345,
#     '6yrs': 0.088483146067,
#     '8yrs': 0.164974619289},
#    'transf_withdrawn_2yr_by': {'2yrs': 0.085778781038,
#     '3yrs': 0.107287449393,
#     '4yrs': 0.133099824869,
#     '6yrs': 0.193820224719,
#     '8yrs': 0.164974619289},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': 0.03036437247,
#     '4yrs': 0.038528896673,
#     '6yrs': 0.058988764045,
#     '8yrs': 0.053299492386},
#    'transf_still_enrolled_2yr_by': {'2yrs': 0.060948081264,
#     '3yrs': 0.034412955466,
#     '4yrs': None,
#     '6yrs': 0.02808988764,
#     '8yrs': 0.021573604061},
#    'transf_still_enrolled_4yr_by': {'2yrs': 0.056433408578,
#     '3yrs': 0.117408906883,
#     '4yrs': 0.098073555166,
#     '6yrs': 0.046348314607,
#     '8yrs': None}},
#   'female': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.175650557621},
#    'completed_by': {'2yrs': 0.047308319739,
#     '3yrs': 0.066570188133,
#     '4yrs': 0.057766367137,
#     '6yrs': 0.078598484848,
#     '8yrs': 0.066914498141},
#    'withdrawn_by': {'2yrs': 0.438825448613,
#     '3yrs': 0.40520984081,
#     '4yrs': 0.415917843389,
#     '6yrs': 0.375946969697,
#     '8yrs': 0.224907063197},
#    'still_enrolled_by': {'2yrs': 0.192495921697,
#     '3yrs': 0.115774240232,
#     '4yrs': 0.069319640565,
#     '6yrs': 0.026515151515,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': 0.079934747145,
#     '3yrs': 0.089725036179,
#     '4yrs': 0.111681643132,
#     '6yrs': 0.107007575758,
#     '8yrs': 0.14405204461},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': 0.040520984081,
#     '4yrs': 0.07188703466,
#     '6yrs': 0.088068181818,
#     '8yrs': 0.121747211896},
#    'transf_withdrawn_2yr_by': {'2yrs': 0.066884176183,
#     '3yrs': 0.098408104197,
#     '4yrs': 0.134788189987,
#     '6yrs': 0.182765151515,
#     '8yrs': 0.140334572491},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': 0.034732272069,
#     '4yrs': 0.03080872914,
#     '6yrs': 0.052083333333,
#     '8yrs': 0.045539033457},
#    'transf_still_enrolled_2yr_by': {'2yrs': 0.05057096248,
#     '3yrs': 0.031837916064,
#     '4yrs': None,
#     '6yrs': 0.032196969697,
#     '8yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': 0.070146818923,
#     '3yrs': 0.091172214182,
#     '4yrs': 0.057766367137,
#     '6yrs': 0.035984848485,
#     '8yrs': 0.015799256506}},
#   'low_inc': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.226928895613},
#    'completed_by': {'2yrs': 0.042319749216,
#     '3yrs': 0.056115107914,
#     '4yrs': 0.040983606557,
#     '6yrs': 0.053680981595,
#     '8yrs': 0.046898638427},
#    'withdrawn_by': {'2yrs': 0.507836990596,
#     '3yrs': 0.469064748201,
#     '4yrs': 0.48243559719,
#     '6yrs': 0.460889570552,
#     '8yrs': 0.236762481089},
#    'still_enrolled_by': {'2yrs': 0.167711598746,
#     '3yrs': 0.087769784173,
#     '4yrs': 0.056206088993,
#     '6yrs': 0.019171779141,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': 0.065830721003,
#     '3yrs': 0.077697841727,
#     '4yrs': 0.088992974239,
#     '6yrs': 0.078220858896,
#     '8yrs': 0.105143721634},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': 0.034532374101,
#     '4yrs': 0.059718969555,
#     '6yrs': 0.068251533742,
#     '8yrs': 0.102118003026},
#    'transf_withdrawn_2yr_by': {'2yrs': 0.065830721003,
#     '3yrs': 0.093525179856,
#     '4yrs': 0.128805620609,
#     '6yrs': 0.196319018405,
#     '8yrs': 0.167170953101},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': 0.037410071942,
#     '4yrs': 0.028103044496,
#     '6yrs': 0.045245398773,
#     '8yrs': 0.038577912254},
#    'transf_still_enrolled_2yr_by': {'2yrs': 0.050156739812,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': 0.056426332288,
#     '3yrs': 0.08345323741,
#     '4yrs': 0.059718969555,
#     '6yrs': 0.030674846626,
#     '8yrs': None}},
#   'mid_inc': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'completed_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'withdrawn_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.38622754491,
#     '6yrs': None,
#     '8yrs': None},
#    'still_enrolled_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_withdrawn_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None}},
#   'no_loan': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'completed_by': {'2yrs': None,
#     '3yrs': 0.057201225741,
#     '4yrs': None,
#     '6yrs': 0.06080634501,
#     '8yrs': 0.049867021277},
#    'withdrawn_by': {'2yrs': 0.480045610034,
#     '3yrs': 0.454545454545,
#     '4yrs': 0.461951656222,
#     '6yrs': 0.440846001322,
#     '8yrs': 0.20079787234},
#    'still_enrolled_by': {'2yrs': 0.187001140251,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': 0.076668869795,
#     '8yrs': 0.107712765957},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.065353625783,
#     '6yrs': 0.084600132188,
#     '8yrs': 0.121010638298},
#    'transf_withdrawn_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.12533572068,
#     '6yrs': 0.172504957039,
#     '8yrs': 0.148936170213},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.045212765957},
#    'transf_still_enrolled_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None}},
#   'no_pell': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'completed_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': 0.407407407407,
#     '8yrs': None},
#    'withdrawn_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.322580645161},
#    'still_enrolled_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_withdrawn_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None}},
#   'high_inc': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'completed_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'withdrawn_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.388888888889,
#     '6yrs': None,
#     '8yrs': None},
#    'still_enrolled_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_withdrawn_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None}},
#   'independ': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.216842105263},
#    'completed_by': {'2yrs': 0.035856573705,
#     '3yrs': 0.066549912434,
#     '4yrs': 0.038284839204,
#     '6yrs': 0.057942057942,
#     '8yrs': 0.048421052632},
#    'withdrawn_by': {'2yrs': 0.49203187251,
#     '3yrs': 0.457092819615,
#     '4yrs': 0.494640122511,
#     '6yrs': 0.474525474525,
#     '8yrs': 0.277894736842},
#    'still_enrolled_by': {'2yrs': 0.159362549801,
#     '3yrs': 0.084063047285,
#     '4yrs': 0.055130168453,
#     '6yrs': 0.020979020979,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.017894736842},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': 0.097609561753,
#     '3yrs': 0.099824868651,
#     '4yrs': 0.111791730475,
#     '6yrs': 0.081918081918,
#     '8yrs': 0.113684210526},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': 0.038528896673,
#     '4yrs': 0.064318529862,
#     '6yrs': 0.074925074925,
#     '8yrs': 0.083157894737},
#    'transf_withdrawn_2yr_by': {'2yrs': 0.051792828685,
#     '3yrs': 0.080560420315,
#     '4yrs': 0.117917304747,
#     '6yrs': 0.165834165834,
#     '8yrs': 0.137894736842},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': 0.049036777583,
#     '4yrs': 0.036753445636,
#     '6yrs': 0.04995004995,
#     '8yrs': 0.042105263158},
#    'transf_still_enrolled_2yr_by': {'2yrs': 0.037848605578,
#     '3yrs': 0.031523642732,
#     '4yrs': None,
#     '6yrs': 0.027972027972,
#     '8yrs': 0.02},
#    'transf_still_enrolled_4yr_by': {'2yrs': 0.061752988048,
#     '3yrs': 0.07180385289,
#     '4yrs': 0.047473200613,
#     '6yrs': 0.030969030969,
#     '8yrs': None}},
#   'first_gen': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.223738062756},
#    'completed_by': {'2yrs': None,
#     '3yrs': 0.061674008811,
#     '4yrs': 0.043269230769,
#     '6yrs': 0.059863945578,
#     '8yrs': None},
#    'withdrawn_by': {'2yrs': 0.486215538847,
#     '3yrs': 0.440528634361,
#     '4yrs': 0.470192307692,
#     '6yrs': 0.450340136054,
#     '8yrs': 0.238744884038},
#    'still_enrolled_by': {'2yrs': 0.187969924812,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.086538461538,
#     '6yrs': 0.073469387755,
#     '8yrs': 0.103001364256},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.066346153846,
#     '6yrs': 0.080272108844,
#     '8yrs': 0.111869031378},
#    'transf_withdrawn_2yr_by': {'2yrs': None,
#     '3yrs': 0.092511013216,
#     '4yrs': 0.126923076923,
#     '6yrs': 0.177551020408,
#     '8yrs': 0.147339699864},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.034615384615,
#     '6yrs': 0.051020408163,
#     '8yrs': 0.043656207367},
#    'transf_still_enrolled_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.024038461538,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': 0.051378446115,
#     '3yrs': 0.090308370044,
#     '4yrs': 0.064423076923,
#     '6yrs': None,
#     '8yrs': None}},
#   'still_enrolled_by': {'2yrs': 0.190476190476,
#    '3yrs': 0.095774647887,
#    '4yrs': 0.061274509804,
#    '6yrs': 0.023350846468,
#    '8yrs': 0.008630609896},
#   'loan_recip': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'completed_by': {'2yrs': None,
#     '3yrs': 0.139534883721,
#     '4yrs': None,
#     '6yrs': 0.105,
#     '8yrs': 0.07264957265},
#    'withdrawn_by': {'2yrs': 0.397058823529,
#     '3yrs': 0.302325581395,
#     '4yrs': 0.364485981308,
#     '6yrs': 0.39,
#     '8yrs': 0.42735042735},
#    'still_enrolled_by': {'2yrs': 0.235294117647,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': 0.105,
#     '8yrs': 0.08547008547},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.121495327103,
#     '6yrs': 0.05,
#     '8yrs': 0.115384615385},
#    'transf_withdrawn_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.121495327103,
#     '6yrs': 0.215,
#     '8yrs': 0.15811965812},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.059829059829},
#    'transf_still_enrolled_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None}},
#   'pell_recip': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'completed_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': 0.060498220641,
#     '8yrs': None},
#    'withdrawn_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.22964264792},
#    'still_enrolled_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_withdrawn_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None}},
#   'not_first_gen': {'died_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'unknown_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': 0.194852941176},
#    'completed_by': {'2yrs': None,
#     '3yrs': 0.076433121019,
#     '4yrs': 0.070652173913,
#     '6yrs': 0.102880658436,
#     '8yrs': None},
#    'withdrawn_by': {'2yrs': 0.408163265306,
#     '3yrs': 0.452229299363,
#     '4yrs': 0.358695652174,
#     '6yrs': 0.341563786008,
#     '8yrs': 0.191176470588},
#    'still_enrolled_by': {'2yrs': 0.204081632653,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_unknown_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': None,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_completed_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.092391304348,
#     '6yrs': 0.119341563786,
#     '8yrs': 0.113970588235},
#    'transf_completed_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.092391304348,
#     '6yrs': 0.082304526749,
#     '8yrs': 0.165441176471},
#    'transf_withdrawn_2yr_by': {'2yrs': None,
#     '3yrs': 0.095541401274,
#     '4yrs': 0.114130434783,
#     '6yrs': 0.17695473251,
#     '8yrs': 0.165441176471},
#    'transf_withdrawn_4yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.054347826087,
#     '6yrs': 0.069958847737,
#     '8yrs': 0.066176470588},
#    'transf_still_enrolled_2yr_by': {'2yrs': None,
#     '3yrs': None,
#     '4yrs': 0.054347826087,
#     '6yrs': None,
#     '8yrs': None},
#    'transf_still_enrolled_4yr_by': {'2yrs': 0.102040816327,
#     '3yrs': 0.108280254777,
#     '4yrs': 0.108695652174,
#     '6yrs': None,
#     '8yrs': None}},
#   'transf_unknown_2yr_by': {'2yrs': None,
#    '3yrs': None,
#    '4yrs': None,
#    '6yrs': None,
#    '8yrs': 0.017836593786},
#   'transf_unknown_4yr_by': {'2yrs': None,
#    '3yrs': None,
#    '4yrs': None,
#    '6yrs': None,
#    '8yrs': None},
#   'transf_completed_2yr_by': {'2yrs': 0.062433862434,
#    '3yrs': 0.075117370892,
#    '4yrs': 0.087418300654,
#    '6yrs': 0.079976649154,
#    '8yrs': 0.104718066743},
#   'transf_completed_4yr_by': {'2yrs': 0.01164021164,
#    '3yrs': 0.037558685446,
#    '4yrs': 0.070261437908,
#    '6yrs': 0.080560420315,
#    '8yrs': 0.120253164557},
#   'transf_withdrawn_2yr_by': {'2yrs': 0.067724867725,
#    '3yrs': 0.092957746479,
#    '4yrs': 0.125,
#    '6yrs': 0.177466433158,
#    '8yrs': 0.150172612198},
#   'transf_withdrawn_4yr_by': {'2yrs': 0.020105820106,
#    '3yrs': 0.040375586854,
#    '4yrs': 0.037581699346,
#    '6yrs': 0.053706946877,
#    '8yrs': 0.047180667434},
#   'transf_still_enrolled_2yr_by': {'2yrs': 0.048677248677,
#    '3yrs': 0.032863849765,
#    '4yrs': 0.028594771242,
#    '6yrs': 0.028021015762,
#    '8yrs': 0.020713463751},
#   'transf_still_enrolled_4yr_by': {'2yrs': 0.059259259259,
#    '3yrs': 0.092957746479,
#    '4yrs': 0.071078431373,
#    '6yrs': 0.037361354349,
#    '8yrs': 0.016110471807}},
#  'separation_date': {'median': '12/31/2999', 'number': 256},
#  '2_yr_completion': {'overall': 945,
#   'low_income': 638,
#   'pell_grant': 928,
#   'high_income': 22,
#   'loan_students': 68,
#   'male_students': 332,
#   'middle_income': 285,
#   'no_pell_grant': 17,
#   'female_students': 613,
#   'no_loan_students': 877,
#   'dependent_students': 443,
#   'independent_students': 502,
#   'first_generation_students': 798,
#   'no_first_generation_students': 147},
#  '3_yr_completion': {'overall': 1065,
#   'low_income': 695,
#   'pell_grant': 1043,
#   'high_income': 21,
#   'loan_students': 86,
#   'male_students': 374,
#   'middle_income': 349,
#   'no_pell_grant': 22,
#   'female_students': 691,
#   'no_loan_students': 979,
#   'dependent_students': 494,
#   'independent_students': 571,
#   'first_generation_students': 908,
#   'no_first_generation_students': 157},
#  '4_yr_completion': {'overall': 1224,
#   'low_income': 854,
#   'pell_grant': 1197,
#   'high_income': 36,
#   'loan_students': 107,
#   'male_students': 445,
#   'middle_income': 334,
#   'no_pell_grant': 27,
#   'female_students': 779,
#   'no_loan_students': 1117,
#   'dependent_students': 571,
#   'independent_students': 653,
#   'first_generation_students': 1040,
#   'no_first_generation_students': 184},
#  '6_yr_completion': {'overall': 1713,
#   'low_income': 1304,
#   'pell_grant': 1686,
#   'high_income': 28,
#   'loan_students': 200,
#   'male_students': 657,
#   'middle_income': 381,
#   'no_pell_grant': 27,
#   'female_students': 1056,
#   'no_loan_students': 1513,
#   'dependent_students': 712,
#   'independent_students': 1001,
#   'first_generation_students': 1470,
#   'no_first_generation_students': 243},
#  '8_yr_completion': {'overall': 1738,
#   'low_income': 1322,
#   'pell_grant': 1707,
#   'high_income': 26,
#   'loan_students': 234,
#   'male_students': 662,
#   'middle_income': 390,
#   'no_pell_grant': 31,
#   'female_students': 1076,
#   'no_loan_students': 1504,
#   'dependent_students': 788,
#   'independent_students': 950,
#   'first_generation_students': 1466,
#   'no_first_generation_students': 272},
#  'rate_suppressed': {'overall': 0.3383,
#   'four_year': 0.3383,
#   'lt_four_year': None,
#   'four_year_100_pooled': None,
#   'four_year_200percent': None,
#   'consumer': {'overall_median': 0.5859, 'median_by_pred_degree': 0.3315},
#   'lt_four_year_100_pooled': None,
#   'lt_four_year_150percent': None},
#  'pooled_yrs_used_pell_150': 2,
#  'completion_rate_4yr_100nt': None,
#  'completion_rate_4yr_150nt': 0.3377,
#  'completion_rate_4yr_200nt': None,
#  'outcome_years': {'om_full_time': 2,
#   'om_part_time': 2,
#   'om_first_time': 2,
#   'om_all_students': 2,
#   'om_not_first_time': 2,
#   'full_time': {'first_time': 2, 'not_first_time': 2},
#   'part_time': {'first_time': 2, 'not_first_time': 2}},
#  'completion_cohort_4yr_100nt': None,
#  'completion_cohort_4yr_150nt': 616,
#  'completion_cohort_4yr_200nt': None,
#  'transfer_rate': {'4yr': {'full_time': 0.112, 'full_time_pooled': 0.099},
#   'cohort_4yr': {'full_time': 616, 'full_time_pooled': 1333},
#   'less_than_4yr': {'full_time': None, 'full_time_pooled': None},
#   'cohort_less_than_4yr': {'full_time': None, 'full_time_pooled': None}},
#  'completion_rate_4yr_150_aian': 0,
#  'completion_rate_4yr_150_nhpi': 0.5,
#  'completion_rate_4yr_150_asian': 0.4762,
#  'completion_rate_4yr_150_black': 0.2414,
#  'completion_rate_4yr_150_white': 0.3282,
#  'completion_rate_l4yr_150_aian': None,
#  'completion_rate_l4yr_150_nhpi': None,
#  'outcome_cohort_nopell': {'all': {'8yr': 2738},
#   'first_time': {'8yr': 1450},
#   'not_first_time': {'8yr': 1288}},
#  'completion_cohort_4yr_150_aian': 1,
#  'completion_cohort_4yr_150_nhpi': 10,
#  'completion_rate_l4yr_150_asian': None,
#  'completion_rate_l4yr_150_black': None,
#  'completion_rate_l4yr_150_white': None,
#  'completion_cohort_4yr_150_asian': 105,
#  'completion_cohort_4yr_150_black': 58,
#  'completion_cohort_4yr_150_white': 131,
#  'completion_rate_4yr_150_2ormore': 0.3,
#  'outcome_years_pell': {'om_full_time': 2,
#   'om_part_time': 2,
#   'om_first_time': 2,
#   'om_all_students': 2,
#   'om_not_first_time': 2,
#   'full_time': {'first_time': 2, 'not_first_time': 2},
#   'part_time': {'first_time': 2, 'not_first_time': 2}},
#  'completion_rate_4yr_150_hispanic': 0.3128,
#  'completion_rate_4yr_150nt_pooled': 0.3383,
#  'completion_rate_4yr_200nt_pooled': None,
#  'completion_rate_l4yr_150_2ormore': None,
#  'completion_cohort_4yr_150_2ormore': 80,
#  'completion_rate_l4yr_150_hispanic': None,
#  'completion_cohort_4yr_150_hispanic': 227,
#  'completion_cohort_4yr_150nt_pooled': 1333,
#  'completion_cohort_4yr_200nt_pooled': None,
#  'completion_rate_four_year_150_pell': 0.3939,
#  'completion_rate_4yr_150_api_pre2010': None,
#  'completion_rate_less_than_4yr_100nt': None,
#  'completion_rate_less_than_4yr_150nt': None,
#  'completion_rate_less_than_4yr_200nt': None,
#  'completion_cohort_four_year_150_pell': 198,
#  'completion_rate_4yr_150_aian_pre2010': None,
#  'completion_rate_4yr_150_race': {'unknown': 0.25},
#  'completion_rate_four_year_100_pooled': None,
#  'completion_rate_l4yr_150_api_pre2010': None,
#  'completion_cohort_4yr_150_api_pre2010': None,
#  'completion_cohort_less_than_4yr_100nt': None,
#  'completion_cohort_less_than_4yr_150nt': None,
#  'completion_cohort_less_than_4yr_200nt': None,
#  'completion_rate_4yr_150_black_pre2010': None,
#  'completion_rate_4yr_150_white_pre2010': None,
#  'completion_rate_l4yr_150_aian_pre2010': None,
#  'completion_rate_l4yr_150_race': {'unknown': None},
#  'completion_rate_lt_four_year_150_pell': None,
#  'completion_cohort_4yr_150_aian_pre2010': None,
#  'completion_cohort_4yr_150_race': {'unknown': 4},
#  'completion_cohort_four_year_100_pooled': None,
#  'completion_rate_l4yr_150_black_pre2010': None,
#  'completion_rate_l4yr_150_white_pre2010': None,
#  'outcome_percentage': {'full_time': {'8yr': {'award': 0.3989,
#     'unknown': 0.3427,
#     'transfer': 0.2477,
#     'still_enrolled': 0.0106},
#    'first_time': {'6yr': {'award': 0.405, 'award_pooled': 0.3987},
#     '8yr': {'award': 0.4406,
#      'unknown': 0.3629,
#      'transfer': 0.1825,
#      'award_pooled': 0.433,
#      'still_enrolled': 0.014,
#      'unknown_pooled': 0.3682,
#      'transfer_pooled': 0.1855,
#      'still_enrolled_pooled': 0.0133}},
#    'not_first_time': {'6yr': {'award': 0.2846, 'award_pooled': 0.2541},
#     '8yr': {'award': 0.3,
#      'unknown': 0.2949,
#      'transfer': 0.4026,
#      'award_pooled': 0.266,
#      'still_enrolled': 0.0026,
#      'unknown_pooled': 0.3203,
#      'transfer_pooled': 0.409,
#      'still_enrolled_pooled': 0.0047}}},
#   'part_time': {'8yr': {'award': 0.178,
#     'unknown': 0.4987,
#     'transfer': 0.3088,
#     'still_enrolled': 0.0144},
#    'first_time': {'6yr': {'award': 0.1911, 'award_pooled': 0.1845},
#     '8yr': {'award': 0.2128,
#      'unknown': 0.6008,
#      'transfer': 0.1704,
#      'award_pooled': 0.2083,
#      'still_enrolled': 0.016,
#      'unknown_pooled': 0.5932,
#      'transfer_pooled': 0.1816,
#      'still_enrolled_pooled': 0.0169}},
#    'not_first_time': {'6yr': {'award': 0.1234, 'award_pooled': 0.1267},
#     '8yr': {'award': 0.1479,
#      'unknown': 0.4101,
#      'transfer': 0.4289,
#      'award_pooled': 0.1466,
#      'still_enrolled': 0.0131,
#      'unknown_pooled': 0.4214,
#      'transfer_pooled': 0.417,
#      'still_enrolled_pooled': 0.015}}},
#   'first_time': {'8yr': {'award': 0.3189,
#     'unknown': 0.4899,
#     'transfer': 0.1761,
#     'still_enrolled': 0.0151}},
#   'all_students': {'8yr': {'award': 0.2587,
#     'unknown': 0.4417,
#     'transfer': 0.2865,
#     'still_enrolled': 0.013}},
#   'not_first_time': {'8yr': {'award': 0.1846,
#     'unknown': 0.3823,
#     'transfer': 0.4226,
#     'still_enrolled': 0.0105}}},
#  'completion_cohort_4yr_150_black_pre2010': None,
#  'completion_cohort_4yr_150_white_pre2010': None,
#  'completion_cohort_lt_four_year_150_pell': None,
#  'completion_rate_lt_four_year_100_pooled': None,
#  'outcome_cohort': {'full_time': {'first_time': {'6yr': 926,
#     '8yr': 926,
#     '6yr_pooled': 1806,
#     '8yr_pooled': 1806},
#    'not_first_time': {'6yr': 390,
#     '8yr': 390,
#     '6yr_pooled': 846,
#     '8yr_pooled': 846}},
#   'part_time': {'first_time': {'6yr': 1062,
#     '8yr': 1062,
#     '6yr_pooled': 2136,
#     '8yr_pooled': 2136},
#    'not_first_time': {'6yr': 1224,
#     '8yr': 1224,
#     '6yr_pooled': 2463,
#     '8yr_pooled': 2463}}},
#  'completion_cohort_less_than_4yr_150_aian': None,
#  'completion_cohort_less_than_4yr_150_nhpi': None,
#  'completion_rate_4yr_150_hispanic_pre2010': None,
#  'completion_cohort_less_than_4yr_150_asian': None,
#  'completion_cohort_less_than_4yr_150_black': None,
#  'completion_cohort_less_than_4yr_150_white': None,
#  'completion_cohort_lt_four_year_100_pooled': None,
#  'completion_rate_4yr_150_nonresident': {'alien': None},
#  'completion_rate_four_year_150_loan_nopell': None,
#  'completion_rate_four_year_150_pell_pooled': 0.3409,
#  'completion_rate_l4yr_150_hispanic_pre2010': None,
#  'rate_suppressed_pell': {'four_year_150_pooled': 0.3409,
#   'lt_four_year_150_pooled': None},
#  'completion_cohort_4yr_150_hispanic_pre2010': None,
#  'completion_rate_l4yr_150_nonresident': {'alien': None},
#  'completion_rate_less_than_4yr_150nt_pooled': None,
#  'completion_rate_less_than_4yr_200nt_pooled': None,
#  'completion_cohort_4yr_150_nonresident': {'alien': 0},
#  'completion_cohort_four_year_150_loan_nopell': None,
#  'completion_cohort_four_year_150_pell_pooled': 440,
#  'completion_cohort_less_than_4yr_150_2ormore': None,
#  'completion_rate_four_year_150_noloan_nopell': 0.311,
#  'outcome_percentage_pell': {'full_time': {'8yr': {'award': 0.3816,
#     'unknown': 0.3836,
#     'transfer': 0.2231,
#     'award_pooled': 0.3456,
#     'still_enrolled': 0.0117,
#     'unknown_pooled': 0.3978,
#     'transfer_pooled': 0.2456,
#     'still_enrolled_pooled': 0.011},
#    'first_time': {'8yr': {'award': 0.4133,
#      'unknown': 0.4017,
#      'transfer': 0.1676,
#      'award_pooled': 0.3936,
#      'still_enrolled': 0.0173,
#      'unknown_pooled': 0.409,
#      'transfer_pooled': 0.1821,
#      'still_enrolled_pooled': 0.0154}},
#    'not_first_time': {'8yr': {'award': 0.3152,
#      'unknown': 0.3455,
#      'transfer': 0.3394,
#      'award_pooled': 0.2546,
#      'still_enrolled': 0,
#      'unknown_pooled': 0.3767,
#      'transfer_pooled': 0.366,
#      'still_enrolled_pooled': 0.0027}}},
#   'part_time': {'8yr': {'award': 0.255,
#     'unknown': 0.4816,
#     'transfer': 0.2465,
#     'award_pooled': 0.2231,
#     'still_enrolled': 0.017,
#     'unknown_pooled': 0.4959,
#     'transfer_pooled': 0.2645,
#     'still_enrolled_pooled': 0.0165},
#    'first_time': {'8yr': {'award': 0.3177,
#      'unknown': 0.5417,
#      'transfer': 0.125,
#      'award_pooled': 0.2444,
#      'still_enrolled': 0.0156,
#      'unknown_pooled': 0.5467,
#      'transfer_pooled': 0.1956,
#      'still_enrolled_pooled': 0.0133}},
#    'not_first_time': {'8yr': {'award': 0.1801,
#      'unknown': 0.4099,
#      'transfer': 0.3913,
#      'award_pooled': 0.199,
#      'still_enrolled': 0.0186,
#      'unknown_pooled': 0.4383,
#      'transfer_pooled': 0.3426,
#      'still_enrolled_pooled': 0.0202}}},
#   'first_time': {'8yr': {'award': 0.3792,
#     'unknown': 0.4517,
#     'transfer': 0.1524,
#     'award_pooled': 0.3359,
#     'still_enrolled': 0.0167,
#     'unknown_pooled': 0.4622,
#     'transfer_pooled': 0.1873,
#     'still_enrolled_pooled': 0.0146}},
#   'all_students': {'8yr': {'award': 0.3299,
#     'unknown': 0.4236,
#     'transfer': 0.2326,
#     'award_pooled': 0.2921,
#     'still_enrolled': 0.0139,
#     'unknown_pooled': 0.4407,
#     'transfer_pooled': 0.2539,
#     'still_enrolled_pooled': 0.0134}},
#   'not_first_time': {'8yr': {'award': 0.2485,
#     'unknown': 0.3773,
#     'transfer': 0.365,
#     'award_pooled': 0.2261,
#     'still_enrolled': 0.0092,
#     'unknown_pooled': 0.4083,
#     'transfer_pooled': 0.354,
#     'still_enrolled_pooled': 0.0116}}},
#  'completion_cohort_less_than_4yr_150_hispanic': None,
#  'completion_cohort_less_than_4yr_150nt_pooled': None,
#  'completion_cohort_less_than_4yr_200nt_pooled': None,
#  'completion_rate_lt_four_year_150_loan_nopell': None,
#  'completion_rate_lt_four_year_150_pell_pooled': None,
#  'outcome_cohort_pell': {'full_time': {'first_time': {'8yr': 346,
#     '8yr_pooled': 714},
#    'not_first_time': {'8yr': 165, '8yr_pooled': 377}},
#   'part_time': {'first_time': {'8yr': 192, '8yr_pooled': 450},
#    'not_first_time': {'8yr': 161, '8yr_pooled': 397}}},
#  'completion_cohort_four_year_150_noloan_nopell': 418,
#  'transfer_rate_suppressed': {'4yr': {'full_time_pooled': 0.099},
#   'less_than_4yr': {'full_time_pooled': None}},
#  'completion_cohort_lt_four_year_150_loan_nopell': None,
#  'completion_cohort_lt_four_year_150_pell_pooled': None,
#  'completion_rate_lt_four_year_150_noloan_nopell': None,
#  'outcome_percentage_nopell': {'first_time': {'8yr': {'award': 0.2966,
#     'unknown': 0.5041,
#     'transfer': 0.1848,
#     'still_enrolled': 0.0145}},
#   'all_students': {'8yr': {'award': 0.2363,
#     'unknown': 0.4474,
#     'transfer': 0.3035,
#     'still_enrolled': 0.0128}},
#   'not_first_time': {'8yr': {'award': 0.1685,
#     'unknown': 0.3835,
#     'transfer': 0.4371,
#     'still_enrolled': 0.0109}}},
#  'completion_cohort_less_than_4yr_150_api_pre2010': None,
#  'completion_cohort_less_than_4yr_150_aian_pre2010': None,
#  'completion_cohort_less_than_4yr_150_race': {'unknown': None},
#  'completion_cohort_lt_four_year_150_noloan_nopell': None,
#  'completion_cohort_less_than_4yr_150_black_pre2010': None,
#  'completion_cohort_less_than_4yr_150_white_pre2010': None,
#  'completion_cohort_less_than_4yr_150_hispanic_pre2010': None,
#  'completion_cohort_less_than_4yr_150_nonresident': {'alien': None},
#  'outcome_percentage_suppressed': {'full_time': {'8yr': {'award_pooled': 0.3797,
#     'unknown_pooled': 0.3529,
#     'transfer_pooled': 0.2568,
#     'still_enrolled_pooled': 0.0106},
#    'first_time': {'6yr': {'award_pooled': 0.3987},
#     '8yr': {'award_pooled': 0.433,
#      'unknown_pooled': 0.3682,
#      'transfer_pooled': 0.1855,
#      'still_enrolled_pooled': 0.0133}},
#    'not_first_time': {'6yr': {'award_pooled': 0.2541},
#     '8yr': {'award_pooled': 0.266,
#      'unknown_pooled': 0.3203,
#      'transfer_pooled': 0.409,
#      'still_enrolled_pooled': 0.0047}}},
#   'part_time': {'8yr': {'award_pooled': 0.1753,
#     'unknown_pooled': 0.5012,
#     'transfer_pooled': 0.3077,
#     'still_enrolled_pooled': 0.0159},
#    'first_time': {'6yr': {'award_pooled': 0.1845},
#     '8yr': {'award_pooled': 0.2083,
#      'unknown_pooled': 0.5932,
#      'transfer_pooled': 0.1816,
#      'still_enrolled_pooled': 0.0169}},
#    'not_first_time': {'6yr': {'award_pooled': 0.1267},
#     '8yr': {'award_pooled': 0.1466,
#      'unknown_pooled': 0.4214,
#      'transfer_pooled': 0.417,
#      'still_enrolled_pooled': 0.015}}},
#   'first_time': {'8yr': {'award_pooled': 0.3113,
#     'unknown_pooled': 0.4901,
#     'transfer_pooled': 0.1834,
#     'still_enrolled_pooled': 0.0152}},
#   'all_students': {'8yr': {'award_pooled': 0.25,
#     'unknown_pooled': 0.447,
#     'transfer_pooled': 0.2891,
#     'still_enrolled_pooled': 0.0139}},
#   'not_first_time': {'8yr': {'award_pooled': 0.1771,
#     'unknown_pooled': 0.3956,
#     'transfer_pooled': 0.4149,
#     'still_enrolled_pooled': 0.0124}}},
#  'outcome_percentage_pell_suppressed': {'full_time': {'8yr': {'award_pooled': 0.3456,
#     'unknown_pooled': 0.3978,
#     'transfer_pooled': 0.2456,
#     'still_enrolled_pooled': 0.011},
#    'first_time': {'8yr': {'award_pooled': 0.3936,
#      'unknown_pooled': 0.409,
#      'transfer_pooled': 0.1821,
#      'still_enrolled_pooled': 0.0154}},
#    'not_first_time': {'8yr': {'award_pooled': 0.2546,
#      'unknown_pooled': 0.3767,
#      'transfer_pooled': 0.366,
#      'still_enrolled_pooled': 0.0027}}},
#   'part_time': {'8yr': {'award_pooled': 0.2231,
#     'unknown_pooled': 0.4959,
#     'transfer_pooled': 0.2645,
#     'still_enrolled_pooled': 0.0165},
#    'first_time': {'8yr': {'award_pooled': 0.2444,
#      'unknown_pooled': 0.5467,
#      'transfer_pooled': 0.1956,
#      'still_enrolled_pooled': 0.0133}},
#    'not_first_time': {'8yr': {'award_pooled': 0.199,
#      'unknown_pooled': 0.4383,
#      'transfer_pooled': 0.3426,
#      'still_enrolled_pooled': 0.0202}}},
#   'first_time': {'8yr': {'award_pooled': 0.3359,
#     'unknown_pooled': 0.4622,
#     'transfer_pooled': 0.1873,
#     'still_enrolled_pooled': 0.0146}},
#   'all_students': {'8yr': {'award_pooled': 0.2921,
#     'unknown_pooled': 0.4407,
#     'transfer_pooled': 0.2539,
#     'still_enrolled_pooled': 0.0134}},
#   'not_first_time': {'8yr': {'award_pooled': 0.2261,
#     'unknown_pooled': 0.4083,
#     'transfer_pooled': 0.354,
#     'still_enrolled_pooled': 0.0116}}}}

# %%
# OPEID
college1.get("ope8_id")
# Out:
# '00129200'

# %% [markdown]
# # Merging

# %%
cc = get_ccc_colleges()

# %%
cc.head()
# Out:
#   CollegeID              CollegeName DistrictID                 StreetAddress  \
# 0       021         Cuyamaca College        020  900 Rancho San Diego Parkway
# 1       022        Grossmont College        020  8800 Grossmont College Drive
# 2       031  Imperial Valley College        030            380 East Aten Road
# 3       051        MiraCosta College        050               1 Barnard Drive
# 4       061          Palomar College        060        1140 West Mission Road
#
#          City     County    Zip ZipPlus4                MailingAddress  \
# 0    El Cajon  San Diego  92019     4304  900 Rancho San Diego Parkway
# 1    El Cajon  San Diego  92020     1799  8800 Grossmont College Drive
# 2    Imperial   Imperial  92251     9787            380 East Aten Road
# 3   Oceanside  San Diego  92056     3899               1 Barnard Drive
# 4  San Marcos  San Diego  92069     1487        1140 West Mission Road
#
#   MailingCity MailingZip         Phone         WebsiteURL   Latitude  \
# 0    El Cajon      92019  619.660.4000   www.cuyamaca.edu  32.744890
# 1    El Cajon      92020  619.644.7000  www.grossmont.edu  32.817897
# 2    Imperial      92251  760.352.8320   www.imperial.edu  32.825859
# 3   Oceanside      92056  760.757.2121  www.miracosta.edu  33.188864
# 4  San Marcos      92069  760.744.1150    www.palomar.edu  33.147015
#
#     Longitude                            LogoURL District
# 0 -116.935229            CuyamacaCollegeLogo.jpg     None
# 1 -117.005640           GrossmontCollegelogo.jpg     None
# 2 -115.502999  ImperialValleyCollegeLogocopy.jpg     None
# 3 -117.301064     Mira_Costa_College_Logo_4c.png     None
# 4 -117.183980             PalomarCollegeLogo.jpg     None

# %%
cc.shape
# Out:
# (115, 17)

# %%
cc_scorecard = pd.DataFrame()

for _, row in cc.iterrows():
    college_name = row["CollegeName"]
    college_city = row["City"]
    time.sleep(0.25)
    print(f"Trying {college_name} in {college_city}")
    try:
        scorecard_data = get_scorecard_by_college(
            college_name = college_name,
            college_city = college_city,
            college_state = "CA"
        )
    except Exception as e:
        print(f"  Error with college {college_name} in {college_city}: {e}")
        print(f"  Retrying with just college name and state.")
        scorecard_data = get_scorecard_by_college(
            college_name = college_name,
            college_state = "CA"
        )
    if not scorecard_data.empty:
        # Track which CCCCO API college this data came from.
        scorecard_data["source_college_name"] = college_name
        cc_scorecard = pd.concat(
            [cc_scorecard, scorecard_data],
            ignore_index=True
        )

print(f"Shape: {cc_scorecard.shape}")
cc_scorecard.head()
# Out:
# Trying Cuyamaca College in El Cajon
# Trying Grossmont College in El Cajon
# Trying Imperial Valley College in Imperial
# Trying MiraCosta College in Oceanside
# Trying Palomar College in San Marcos
# Trying San Diego City College in San Diego
# Trying San Diego Mesa College in San Diego
# Trying San Diego Miramar College in San Diego
# Trying Southwestern College in Chula Vista
# Trying Butte College in Oroville
# Trying Feather River College in Quincy
# Trying Lassen Community College in Susanville
# Trying Mendocino College in Ukiah
# Trying College of the Redwoods in Eureka
# Trying Shasta College in Redding
# Trying College of the Siskiyous in Weed
# Trying Lake Tahoe Community College in So. Lake Tahoe
#   Error with college Lake Tahoe Community College in So. Lake Tahoe: "None of [Index(['school_name'], dtype='object')] are in the [columns]"
#   Retrying with just college name and state.
# Trying American River College in Sacramento
# Trying Cosumnes River College in Sacramento
# Trying Sacramento City College in Sacramento
# Trying Folsom Lake College in Folsom
# Trying Napa Valley College in Napa
# Trying Santa Rosa Junior College in Santa Rosa
# Trying Sierra College in Rocklin
# Trying Solano Community College in Fairfield
# Trying Yuba College in Marysville
# Trying Woodland Community College in Woodland
# Trying Contra Costa College in San Pablo
# Trying Diablo Valley College in Pleasant Hill
# Trying Los Medanos College in Pittsburg
# Trying College of Marin in Kentfield
# Trying College of Alameda in Alameda
# Trying Laney College in Oakland
# Trying Merritt College in Oakland
# Trying Berkeley City College in Berkeley
# Trying City College of San Francisco in San Francisco
# Trying Cañada College in Redwood City
# Trying College of San Mateo in San Mateo
# Trying Skyline College in San Bruno
# Trying Cabrillo College in Aptos
# Trying De Anza College in Cupertino
# Trying Foothill College in Los Altos Hills
# Trying Ohlone College in Fremont
# Trying Gavilan College in Gilroy
# Trying Hartnell College in Salinas
# Trying Monterey Peninsula College in Monterey
# Trying Evergreen Valley College in San Jose
# Trying San José City College in San Jose
# Trying Las Positas College in Livermore
# Trying Chabot College in Hayward
# Trying Mission College in Santa Clara
# Trying West Valley College in Saratoga
# Trying Bakersfield College in Bakersfield
# Trying Cerro Coso Community College in Ridgecrest
# Trying Porterville College in Porterville
# Trying Merced College in Merced
# Trying San Joaquin Delta College in Stockton
# Trying College of the Sequoias in Visalia
# Trying Fresno City College in Fresno
# Trying Reedley College in Reedley
# Trying Madera Community College in Madera
# Trying Clovis Community College in Fresno
# Trying Coalinga College in Coalinga
# Trying Lemoore College in Lemoore
# Trying Columbia College in Sonora
# Trying Modesto Junior College in Modesto
# Trying Allan Hancock College in Santa Maria
# Trying Antelope Valley College in Lancaster
# Trying Cuesta College in San Luis Obispo
# Trying Santa Barbara City College in Santa Barbara
# Trying College of the Canyons in Santa Clarita
# Trying Moorpark College in Moorpark
# Trying Oxnard College in Oxnard
# Trying Ventura College in Ventura
# Trying Taft College in Taft
# Trying Compton College in Compton
# Trying El Camino College in Torrance
# Trying Glendale Community College in Glendale
# Trying Los Angeles City College in Los Angeles
# Trying Los Angeles Harbor College in Wilmington
# Trying Los Angeles Mission College in Sylmar
# Trying Los Angeles Pierce College in Woodland Hills
# Trying Los Angeles Southwest College in Los Angeles
# Trying Los Angeles Trade-Technical College in Los Angeles
# Trying Los Angeles Valley College in Van Nuys
#   Error with college Los Angeles Valley College in Van Nuys: "None of [Index(['school_name'], dtype='object')] are in the [columns]"
#   Retrying with just college name and state.
# Trying East Los Angeles College in Monterey Park
# Trying West Los Angeles College in Culver City
# Trying Pasadena City College in Pasadena
# Trying Santa Monica College in Santa Monica
# Trying Cerritos College in Norwalk
# Trying Citrus College in Glendora
# Trying Coastline College in Fountain Valley
# Trying Golden West College in Huntington Beach
# Trying Orange Coast College in Costa Mesa
# Trying Long Beach City College in Long Beach
# Trying Mt. San Antonio College in Walnut
# Trying Cypress College in Cypress
# Trying Fullerton College in Fullerton
# Trying Santa Ana College in Santa Ana
# Trying Santiago Canyon College in Orange
# Trying Rio Hondo College in Whittier
# Trying Saddleback College in Mission Viejo
# Trying Irvine Valley College in Irvine
# Trying Barstow Community College in Barstow
# Trying Chaffey College in Rancho Cucamonga
# Trying College of the Desert in Palm Desert
# Trying Mt. San Jacinto College in San Jacinto
# Trying Palo Verde College in Blythe
# Trying Riverside City College in Riverside
# Trying Moreno Valley College in Moreno Valley
# Trying Norco College in Norco
# Trying Copper Mountain College in Joshua Tree
# Trying Crafton Hills College in Yucaipa
# Trying San Bernardino Valley College in San Bernardino
# Trying Victor Valley College in Victorville
# Shape: (126, 9)
#                school_name  latest_student_size  \
# 0         Cuyamaca College               6788.0
# 1        Grossmont College              11467.0
# 2  Imperial Valley College               6881.0
# 3        MiraCosta College              10474.0
# 4          Palomar College              16167.0
#
#    latest_student_enrollment_undergrad_12_month  \
# 0                                       12859.0
# 1                                       18592.0
# 2                                       10716.0
# 3                                       16640.0
# 4                                       25877.0
#
#    latest_student_demographics_over_23_at_entry  \
# 0                                          0.47
# 1                                          0.39
# 2                                          0.26
# 3                                          0.43
# 4                                          0.44
#
#    latest_student_demographics_first_generation  \
# 0                                      0.610113
# 1                                      0.550389
# 2                                      0.609207
# 3                                      0.509714
# 4                                      0.538365
#
#    latest_student_demographics_median_hh_income  \
# 0                                       61734.0
# 1                                       60424.0
# 2                                       45460.0
# 3                                       68755.0
# 4                                       68227.0
#
#    latest_student_demographics_student_faculty_ratio  \
# 0                                               25.0
# 1                                               23.0
# 2                                               33.0
# 3                                               22.0
# 4                                               24.0
#
#    latest_student_FAFSA_applications      source_college_name
# 0                             2901.0         Cuyamaca College
# 1                             5463.0        Grossmont College
# 2                             3798.0  Imperial Valley College
# 3                             4602.0        MiraCosta College
# 4                             5316.0          Palomar College

# %%
cc_scorecard.shape
# Out:
# (137, 9)

# %%
cc_scorecard["source_college_name"].value_counts()
# Out:
# source_college_name
# Bakersfield College        4
# Santa Ana College          3
# Fullerton College          2
# Shasta College             2
# Ventura College            2
#                           ..
# Berkeley City College      1
# Merritt College            1
# Laney College              1
# College of Alameda         1
# College of the Sequoias    1
# Name: count, Length: 115, dtype: int64

# %%
# returns rows belonging to source_college_name groups with count > 1
dups = cc_scorecard.groupby("source_college_name").filter(lambda g: len(g) > 1)
dups
# Out:
#                                            school_name  latest_student_size  \
# 14            Shasta Bible College and Graduate School                 12.0
# 15                                      Shasta College               5536.0
# 53   Glendale Career College-North-West College-Bak...                387.0
# 54                                 Bakersfield College              16451.0
# 55              San Joaquin Valley College-Bakersfield                820.0
# 56                             UEI College-Bakersfield               1385.0
# 58                                 Porterville College               2775.0
# 59              San Joaquin Valley College-Porterville                 98.0
# 78                                     Ventura College               9971.0
# 79                      The Colleges of Law at Ventura                  NaN
# 97                         Coastline Community College               7007.0
# 98                            Coastline Beauty College                185.0
# 104                      Hope International University                549.0
# 105                                  Fullerton College              16637.0
# 106                           Santa Ana Beauty College                 74.0
# 107                                  Santa Ana College              22011.0
# 108  American College of Healthcare and Technology-...                 85.0
# 124                              Victor Valley College              12107.0
# 125  Victor Valley Community College - Aviation Tec...                  NaN
#
#      latest_student_enrollment_undergrad_12_month  \
# 14                                           35.0
# 15                                        11483.0
# 53                                          398.0
# 54                                        39530.0
# 55                                         1285.0
# 56                                         2447.0
# 58                                         5624.0
# 59                                          124.0
# 78                                        16174.0
# 79                                            NaN
# 97                                        14752.0
# 98                                          318.0
# 104                                         616.0
# 105                                       26447.0
# 106                                         131.0
# 107                                       38105.0
# 108                                         108.0
# 124                                       15112.0
# 125                                           NaN
#
#      latest_student_demographics_over_23_at_entry  \
# 14                                           0.26
# 15                                           0.48
# 53                                           0.63
# 54                                           0.36
# 55                                           0.49
# 56                                           0.60
# 58                                           0.35
# 59                                           0.49
# 78                                           0.36
# 79                                            NaN
# 97                                           0.73
# 98                                            NaN
# 104                                          0.44
# 105                                          0.30
# 106                                           NaN
# 107                                          0.32
# 108                                          0.66
# 124                                          0.48
# 125                                          0.48
#
#      latest_student_demographics_first_generation  \
# 14                                            NaN
# 15                                       0.526534
# 53                                       0.551724
# 54                                       0.630508
# 55                                       0.590503
# 56                                       0.640536
# 58                                       0.630058
# 59                                       0.590503
# 78                                       0.566563
# 79                                            NaN
# 97                                       0.554903
# 98                                       0.718750
# 104                                      0.386313
# 105                                      0.532743
# 106                                      0.787234
# 107                                      0.696058
# 108                                      0.684358
# 124                                      0.564726
# 125                                      0.564726
#
#      latest_student_demographics_median_hh_income  \
# 14                                        54363.0
# 15                                        46241.0
# 53                                        58741.0
# 54                                        46274.0
# 55                                        51804.0
# 56                                        46280.0
# 58                                        42464.0
# 59                                        51804.0
# 78                                        68802.0
# 79                                            NaN
# 97                                        68030.0
# 98                                            NaN
# 104                                       71774.0
# 105                                       69818.0
# 106                                           NaN
# 107                                       69027.0
# 108                                       58577.0
# 124                                       53361.0
# 125                                       53361.0
#
#      latest_student_demographics_student_faculty_ratio  \
# 14                                                 3.0
# 15                                                26.0
# 53                                                28.0
# 54                                                32.0
# 55                                                19.0
# 56                                                21.0
# 58                                                19.0
# 59                                                49.0
# 78                                                27.0
# 79                                                 NaN
# 97                                                32.0
# 98                                                20.0
# 104                                               13.0
# 105                                               24.0
# 106                                               24.0
# 107                                               32.0
# 108                                               15.0
# 124                                               23.0
# 125                                                NaN
#
#      latest_student_FAFSA_applications    source_college_name
# 14                                22.0         Shasta College
# 15                              3202.0         Shasta College
# 53                               934.0    Bakersfield College
# 54                              8128.0    Bakersfield College
# 55                              8837.0    Bakersfield College
# 56                              3361.0    Bakersfield College
# 58                              1845.0    Porterville College
# 59                              8837.0    Porterville College
# 78                              3326.0        Ventura College
# 79                                 NaN        Ventura College
# 97                              2924.0      Coastline College
# 98                               219.0      Coastline College
# 104                              515.0      Fullerton College
# 105                             6986.0      Fullerton College
# 106                              131.0      Santa Ana College
# 107                             3832.0      Santa Ana College
# 108                              618.0      Santa Ana College
# 124                             6062.0  Victor Valley College
# 125                             6062.0  Victor Valley College

# %%
for school in cc_scorecard["school_name"].unique():
    print(school)
# Out:
# Cuyamaca College
# Grossmont College
# Imperial Valley College
# MiraCosta College
# MiraCosta College - San Elijo Campus
# Palomar College
# San Diego City College
# San Diego Mesa College
# San Diego Miramar College
# Southwestern College
# Northwestern College
# Southwestern Illinois College
# Florida SouthWestern State College
# Southwestern Community College
# Southwestern Michigan College
# Southwestern Oregon Community College
# Southwestern Christian College
# Butte College
# Feather River Community College District
# Lassen Community College
# Mendocino College
# College of the Redwoods
# Shasta Bible College and Graduate School
# Shasta College
# College of the Siskiyous
# Lake Tahoe Community College
# American River College
# Cosumnes River College
# Sacramento City College
# Folsom Lake College
# Napa Valley College
# Santa Rosa Junior College
# Sierra College
# Sierra College of Beauty
# Solano Community College
# Yuba College
# Woodland Community College
# Contra Costa College
# Contra Costa Medical Career College
# Diablo Valley College
# Los Medanos College
# College of Marin
# College of Alameda
# Laney College
# Merritt College
# Berkeley College-New York
# Berkeley City College
# City College of San Francisco
# Canada College
# College of San Mateo
# Skyline College
# Cabrillo College
# De Anza College
# Foothill College
# Ohlone College
# Gavilan College
# Hartnell College
# Monterey Peninsula College
# Evergreen Valley College
# San Jose City College
# Las Positas College
# Chabot College
# Los Angeles Mission College
# Mission College
# SUM Bible College and Theological Seminary
# Bethany Global University
# Christ Mission College
# West Valley College
# Glendale Career College-North-West College-Bakersfield
# Bakersfield College
# San Joaquin Valley College-Bakersfield
# UEI College-Bakersfield
# Cerro Coso Community College
# Porterville College
# San Joaquin Valley College-Porterville
# Merced College
# San Joaquin Delta College
# College of the Sequoias
# Fresno City College
# Reedley College
# Madera Community College
# Clovis Community College
# Coalinga College
# Lemoore College
# Columbia College
# Fortis College-Columbia
# Columbia State Community College
# Howard Community College
# Teachers College at Columbia University
# Lower Columbia College
# Columbia College - Whiteman AFB
# Columbia College - Kansas City
# Columbia College - Crystal Lake Campus
# Columbia College - Orlando
# Columbia College - NAS Jacksonville
# Columbia College - Redstone Arsenal
# Southeastern College-Columbia
# Columbia Gorge Community College
# Columbia Basin College
# Columbia-Greene Community College
# Lincoln College of Technology-Columbia
# Modesto Junior College
# Allan Hancock College
# Antelope Valley Community College District
# Cuesta College
# Santa Barbara City College
# College of the Canyons
# Moorpark College
# Oxnard College
# Ventura College
# The Colleges of Law at Ventura
# Taft College
# Compton College
# El Camino Community College District
# Glendale Community College
# Los Angeles City College
# Los Angeles Harbor College
# Los Angeles Pierce College
# Los Angeles Southwest College
# Los Angeles Trade Technical College
# Los Angeles Valley College
# East Los Angeles College
# West Los Angeles College
# Pasadena City College
# Santa Monica College
# Cerritos College
# Citrus College
# Citrus Heights Beauty College
# Coastline Community College
# Coastline Beauty College
# Coastline Beauty College - Hemet
# Golden West College
# Orange Coast College
# Long Beach City College
# Chamberlain University-Texas
# Mt San Antonio College
# San Antonio College
# Galen College of Nursing-San Antonio
# The College of Health Care Professions-San Antonio
# Miller-Motte College-STVT-San Antonio
# Concorde Career College-San Antonio
# Vogue College of Cosmetology-San Antonio Fredericksburg
# The College of Health Care Professions-South San Antonio
# Cypress College
# Hope International University
# Fullerton College
# Santa Ana Beauty College
# Santa Ana College
# American College of Healthcare and Technology-Santa Ana
# Santiago Canyon College
# Rio Hondo College
# Saddleback College
# Irvine Valley College
# Barstow Community College
# Chaffey College
# College of the Desert
# San Jacinto Community College
# Mt San Jacinto Community College District
# San Jacinto College-North Campus
# San Jacinto College-South Campus
# San Jacinto Community College District - Generation Park Campus
# Palo Verde College
# Riverside City College
# Moreno Valley College
# Norco College
# Copper Mountain Community College
# Crafton Hills College
# San Bernardino Valley College
# Victor Valley College
# Victor Valley Community College - Aviation Technology
