# %% [markdown]
# # Cleaning and Normalizing Data Mart Files
#
# The files downloaded directly from the [CCC Data Mart](https://datamart.cccco.edu/) are not formatted well. The purpose of this set of scripts is to clean up those files of unhelpful formatting and to normalize for analysis.
#
# For the associated cleaning and denormalization of the EOPS files, see `./ucd_sta_221_project/data_files/cc_eops/clean_eops.ipynb`.

# %%
import pandas as pd

# %%
top_code = {
    "math": "170100",
    "engl": "150100"
}

# %%
path = "ucd_sta_221_project/data_files"
file = f"datamart_math_success_retention_{top_code.get("math")}"

math = pd.read_csv(
    f"{path}/{file}.csv",
    header=None
)
math = math.drop(index=1).reset_index(drop=True) # Contains the word "Transferable"
math.head()
# Out:
#               0                 1                2              3    \
# 0             NaN         Fall 2011        Fall 2011      Fall 2011
# 1             NaN  Enrollment Count  Retention Count  Success Count
# 2         Alameda               563              441            374
# 3   Allan Hancock               965              785            615
# 4  American River             2,879            2,278          1,826
#
#               4             5                 6                7    \
# 0       Fall 2011     Fall 2011         Fall 2012        Fall 2012
# 1  Retention Rate  Success Rate  Enrollment Count  Retention Count
# 2          78.33%        66.43%               578              470
# 3          81.35%        63.73%             1,056              833
# 4          79.12%        63.42%             2,683            2,206
#
#              8               9    ...               231              232  \
# 0      Fall 2012       Fall 2012  ...       Winter 2022      Winter 2022
# 1  Success Count  Retention Rate  ...  Enrollment Count  Retention Count
# 2            379          81.31%  ...               NaN              NaN
# 3            667          78.88%  ...               NaN              NaN
# 4          1,761          82.22%  ...               NaN              NaN
#
#              233             234           235               236  \
# 0    Winter 2022     Winter 2022   Winter 2022       Winter 2023
# 1  Success Count  Retention Rate  Success Rate  Enrollment Count
# 2            NaN             NaN           NaN               NaN
# 3            NaN             NaN           NaN               NaN
# 4            NaN             NaN           NaN               NaN
#
#                237            238             239           240
# 0      Winter 2023    Winter 2023     Winter 2023   Winter 2023
# 1  Retention Count  Success Count  Retention Rate  Success Rate
# 2              NaN            NaN             NaN           NaN
# 3              NaN            NaN             NaN           NaN
# 4              NaN            NaN             NaN           NaN
#
# [5 rows x 241 columns]

# %%
new_cols = [f"{a} {b}".strip('_') for a, b in zip(math.iloc[0], math.iloc[1])]
math.columns = new_cols
math.rename(columns={"nan nan": "College"}, inplace=True)
math = math.drop(index=[0, 1]).reset_index(drop=True)  # drop the first two rows

math.head()
# Out:
#            College Fall 2011 Enrollment Count Fall 2011 Retention Count  \
# 0          Alameda                        563                       441
# 1    Allan Hancock                        965                       785
# 2   American River                      2,879                     2,278
# 3  Antelope Valley                      1,366                     1,117
# 4      Bakersfield                      1,144                       891
#
#   Fall 2011 Success Count Fall 2011 Retention Rate Fall 2011 Success Rate  \
# 0                     374                   78.33%                 66.43%
# 1                     615                   81.35%                 63.73%
# 2                   1,826                   79.12%                 63.42%
# 3                     922                   81.77%                 67.50%
# 4                     565                   77.88%                 49.39%
#
#   Fall 2012 Enrollment Count Fall 2012 Retention Count  \
# 0                        578                       470
# 1                      1,056                       833
# 2                      2,683                     2,206
# 3                      1,409                     1,178
# 4                      1,252                     1,011
#
#   Fall 2012 Success Count Fall 2012 Retention Rate  ...  \
# 0                     379                   81.31%  ...
# 1                     667                   78.88%  ...
# 2                   1,761                   82.22%  ...
# 3                     945                   83.61%  ...
# 4                     675                   80.75%  ...
#
#   Winter 2022 Enrollment Count Winter 2022 Retention Count  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#   Winter 2022 Success Count Winter 2022 Retention Rate  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#   Winter 2022 Success Rate Winter 2023 Enrollment Count  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
#
#   Winter 2023 Retention Count Winter 2023 Success Count  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#   Winter 2023 Retention Rate Winter 2023 Success Rate
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
# [5 rows x 241 columns]

# %%
# keep only headcounts. We will re-compute rates later
math.columns = math.columns.str.strip()
cols_to_keep = ["College"]
cols_to_keep += [c for c in math.columns if c.endswith("Count")]
math = math.loc[:, cols_to_keep].copy()

math.head()
# Out:
#            College Fall 2011 Enrollment Count Fall 2011 Retention Count  \
# 0          Alameda                        563                       441
# 1    Allan Hancock                        965                       785
# 2   American River                      2,879                     2,278
# 3  Antelope Valley                      1,366                     1,117
# 4      Bakersfield                      1,144                       891
#
#   Fall 2011 Success Count Fall 2012 Enrollment Count  \
# 0                     374                        578
# 1                     615                      1,056
# 2                   1,826                      2,683
# 3                     922                      1,409
# 4                     565                      1,252
#
#   Fall 2012 Retention Count Fall 2012 Success Count  \
# 0                       470                     379
# 1                       833                     667
# 2                     2,206                   1,761
# 3                     1,178                     945
# 4                     1,011                     675
#
#   Fall 2013 Enrollment Count Fall 2013 Retention Count  \
# 0                        539                       422
# 1                      1,101                       878
# 2                      2,566                     2,055
# 3                      1,488                     1,218
# 4                      1,360                     1,097
#
#   Fall 2013 Success Count  ... Winter 2020 Success Count  \
# 0                     307  ...                       NaN
# 1                     691  ...                       NaN
# 2                   1,715  ...                       NaN
# 3                     982  ...                       227
# 4                     695  ...                       NaN
#
#   Winter 2021 Enrollment Count Winter 2021 Retention Count  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#   Winter 2021 Success Count Winter 2022 Enrollment Count  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#   Winter 2022 Retention Count Winter 2022 Success Count  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#   Winter 2023 Enrollment Count Winter 2023 Retention Count  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#   Winter 2023 Success Count
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 145 columns]

# %%
cols_to_cast = [c for c in math.columns if c != "College"]

math[cols_to_cast] = math[cols_to_cast].replace({",": ""}, regex=True)

math[cols_to_cast] = (
    math[cols_to_cast]
    .apply(pd.to_numeric, errors="coerce")
    .astype("Int64")
)

math.head()
# Out:
#            College  Fall 2011 Enrollment Count  Fall 2011 Retention Count  \
# 0          Alameda                         563                        441
# 1    Allan Hancock                         965                        785
# 2   American River                        2879                       2278
# 3  Antelope Valley                        1366                       1117
# 4      Bakersfield                        1144                        891
#
#    Fall 2011 Success Count  Fall 2012 Enrollment Count  \
# 0                      374                         578
# 1                      615                        1056
# 2                     1826                        2683
# 3                      922                        1409
# 4                      565                        1252
#
#    Fall 2012 Retention Count  Fall 2012 Success Count  \
# 0                        470                      379
# 1                        833                      667
# 2                       2206                     1761
# 3                       1178                      945
# 4                       1011                      675
#
#    Fall 2013 Enrollment Count  Fall 2013 Retention Count  \
# 0                         539                        422
# 1                        1101                        878
# 2                        2566                       2055
# 3                        1488                       1218
# 4                        1360                       1097
#
#    Fall 2013 Success Count  ...  Winter 2020 Success Count  \
# 0                      307  ...                       <NA>
# 1                      691  ...                       <NA>
# 2                     1715  ...                       <NA>
# 3                      982  ...                        227
# 4                      695  ...                       <NA>
#
#    Winter 2021 Enrollment Count  Winter 2021 Retention Count  \
# 0                          <NA>                         <NA>
# 1                          <NA>                         <NA>
# 2                          <NA>                         <NA>
# 3                          <NA>                         <NA>
# 4                          <NA>                         <NA>
#
#    Winter 2021 Success Count  Winter 2022 Enrollment Count  \
# 0                       <NA>                          <NA>
# 1                       <NA>                          <NA>
# 2                       <NA>                          <NA>
# 3                       <NA>                          <NA>
# 4                       <NA>                          <NA>
#
#    Winter 2022 Retention Count  Winter 2022 Success Count  \
# 0                         <NA>                       <NA>
# 1                         <NA>                       <NA>
# 2                         <NA>                       <NA>
# 3                         <NA>                       <NA>
# 4                         <NA>                       <NA>
#
#    Winter 2023 Enrollment Count  Winter 2023 Retention Count  \
# 0                          <NA>                         <NA>
# 1                          <NA>                         <NA>
# 2                          <NA>                         <NA>
# 3                          <NA>                         <NA>
# 4                          <NA>                         <NA>
#
#    Winter 2023 Success Count
# 0                       <NA>
# 1                       <NA>
# 2                       <NA>
# 3                       <NA>
# 4                       <NA>
#
# [5 rows x 145 columns]

# %%
# Winter intersession terms are very short and not representative;
# drop these columns
math.columns = math.columns.str.strip()
cols_to_drop = [c for c in math.columns if "Winter" in c]
math = math.drop(columns=cols_to_drop)

math.head()
# Out:
#            College  Fall 2011 Enrollment Count  Fall 2011 Retention Count  \
# 0          Alameda                         563                        441
# 1    Allan Hancock                         965                        785
# 2   American River                        2879                       2278
# 3  Antelope Valley                        1366                       1117
# 4      Bakersfield                        1144                        891
#
#    Fall 2011 Success Count  Fall 2012 Enrollment Count  \
# 0                      374                         578
# 1                      615                        1056
# 2                     1826                        2683
# 3                      922                        1409
# 4                      565                        1252
#
#    Fall 2012 Retention Count  Fall 2012 Success Count  \
# 0                        470                      379
# 1                        833                      667
# 2                       2206                     1761
# 3                       1178                      945
# 4                       1011                      675
#
#    Fall 2013 Enrollment Count  Fall 2013 Retention Count  \
# 0                         539                        422
# 1                        1101                        878
# 2                        2566                       2055
# 3                        1488                       1218
# 4                        1360                       1097
#
#    Fall 2013 Success Count  ...  Summer 2020 Success Count  \
# 0                      307  ...                        434
# 1                      691  ...                        322
# 2                     1715  ...                       1289
# 3                      982  ...                        697
# 4                      695  ...                       1080
#
#    Summer 2021 Enrollment Count  Summer 2021 Retention Count  \
# 0                           239                          199
# 1                           290                          224
# 2                          1438                         1151
# 3                           822                          711
# 4                          1159                         1014
#
#    Summer 2021 Success Count  Summer 2022 Enrollment Count  \
# 0                        172                           390
# 1                        170                           282
# 2                       1015                          1392
# 3                        597                           748
# 4                        761                          1204
#
#    Summer 2022 Retention Count  Summer 2022 Success Count  \
# 0                          317                        294
# 1                          217                        182
# 2                         1190                       1061
# 3                          587                        449
# 4                         1064                        818
#
#    Summer 2023 Enrollment Count  Summer 2023 Retention Count  \
# 0                           480                          430
# 1                           339                          264
# 2                          1742                         1438
# 3                           880                          747
# 4                          1137                         1001
#
#    Summer 2023 Success Count
# 0                        397
# 1                        202
# 2                       1261
# 3                        617
# 4                        812
#
# [5 rows x 109 columns]

# %%
def get_academic_year_terms(year: str):
    """
    Given a year as a string (e.g., "2023"), return a list of academic terms
    for that academic year in the format:
    - Fall {previous_year}
    - Spring {year}
    - Summer {year}

    :param year: The year for which to generate academic terms.
    :return: A list of academic terms for the specified year.
    """
    return [
        f"Fall {int(year) - 1}",
        f"Spring {year}",
        f"Summer {year}"
    ]

get_academic_year_terms("2012")
# Out:
# ['Fall 2011', 'Spring 2012', 'Summer 2012']

# %%
def build_rates_by_year(year: str, rate: str, df: pd.DataFrame):
    """ 
    Given a reporting year and a rate type (e.g., "Success" or "Retention"),
    computes the rate by summing over each associated term in the reporting year
    and then dividing the appropriate counts.

    :param year: The reporting year as a string (e.g., "2012").
    :param rate: The type of rate to compute ("Success" or "Retention").
    """

    terms = get_academic_year_terms(year)
    if rate == "Success":
        num_cols = [f"{term} Success Count" for term in terms]
        denom_cols = [f"{term} Enrollment Count" for term in terms]
    elif rate == "Retention":
        num_cols = [f"{term} Retention Count" for term in terms]
        denom_cols = [f"{term} Enrollment Count" for term in terms]
    else:
        raise ValueError("Rate must be either 'Success' or 'Retention'.")

    df[f"{year} {rate} Rate"] = (
        df[num_cols].sum(axis=1) / df[denom_cols].sum(axis=1)
    )

    df.drop(columns = num_cols, inplace=True)

    return df

# %%
def build_rates(years: list[str], df: pd.DataFrame):
    """
    Given a list of reporting years, computes the Success and Retention rates
    for each combination and updates the DataFrame in place.

    :param years: A list of reporting years as strings (e.g., ["2012", "2013"]).
    :param df: The DataFrame containing the data.
    """
    for year in years:
        for rate in ["Success", "Retention"]:
            df = build_rates_by_year(year, rate, df)
            
    
    # Drop Enrollment Count columns after rates are computed
    df.columns = df.columns.str.strip()
    cols_to_drop = [
        c for c in df.columns if "Enrollment Count" in c
    ]
    df.drop(columns=cols_to_drop, inplace=True)

# %%
build_rates(range(2012, 2024), math)

math.head()
# Out:
#            College  2012 Success Rate  2012 Retention Rate  2013 Success Rate  \
# 0          Alameda           0.658505             0.782861           0.687571
# 1    Allan Hancock           0.662719             0.814912           0.638959
# 2   American River           0.663519             0.806916           0.680633
# 3  Antelope Valley           0.671954             0.812906           0.693925
# 4      Bakersfield           0.521361              0.77057           0.557572
#
#    2013 Retention Rate  2014 Success Rate  2014 Retention Rate  \
# 0             0.827119           0.593932             0.783086
# 1             0.801008           0.628675             0.788159
# 2              0.83023           0.693865             0.831361
# 3             0.841121           0.679663             0.825951
# 4             0.821005           0.556136             0.818211
#
#    2015 Success Rate  2015 Retention Rate  2016 Success Rate  ...  \
# 0           0.644478             0.807867           0.628716  ...
# 1           0.643123             0.807435           0.639649  ...
# 2           0.680416              0.82664           0.694554  ...
# 3            0.65071             0.794322           0.660872  ...
# 4           0.547016              0.81947            0.54734  ...
#
#    2019 Success Rate  2019 Retention Rate  2020 Success Rate  \
# 0           0.675766             0.839559           0.755714
# 1           0.573333             0.772403           0.649419
# 2           0.667904             0.824101           0.735113
# 3           0.662455              0.82309           0.664897
# 4           0.623449              0.85701           0.632417
#
#    2020 Retention Rate  2021 Success Rate  2021 Retention Rate  \
# 0             0.842052           0.644656             0.780803
# 1             0.816823           0.629732             0.811634
# 2             0.841244           0.689805             0.804262
# 3             0.828358           0.649294             0.837546
# 4             0.838144           0.556286             0.815237
#
#    2022 Success Rate  2022 Retention Rate  2023 Success Rate  \
# 0           0.662632             0.781392           0.698471
# 1            0.51973              0.72947            0.51912
# 2            0.68156             0.811592            0.66911
# 3           0.594568             0.802598           0.607321
# 4           0.554434              0.80855           0.570719
#
#    2023 Retention Rate
# 0             0.834251
# 1             0.762965
# 2             0.809948
# 3             0.805324
# 4             0.836521
#
# [5 rows x 25 columns]

# %%
# reshape math from wide (one column per year + metric) to long with one row
# per (College, Year)
cols = [c for c in math.columns if c != "College"]

long = math.melt(
    id_vars="College",
    value_vars=cols,
    var_name="year_metric",
    value_name="value"
)

# split the "YYYY Metric" column into Year and Metric
long = long.assign(
    Year=long["year_metric"].str.extract(r"^(\d{4})")[0].astype(int),
    Metric=long["year_metric"].str.replace(r"^\d{4}\s+", "", regex=True).str.strip()
).drop(columns="year_metric")

# pivot so each row is College, Year, Success Rate, Retention Rate
math_yearly = (
    long.pivot_table(
        index=["Year", "College"],
        columns="Metric",
        values="value"
    ).reset_index()
)

math_yearly.columns.name = None
math_yearly = math_yearly.sort_values(["Year", "College"]).reset_index(drop=True)

math_yearly.head()
# Out:
#    Year          College  Retention Rate  Success Rate
# 0  2012          Alameda        0.782861      0.658505
# 1  2012    Allan Hancock        0.814912      0.662719
# 2  2012   American River        0.806916      0.663519
# 3  2012  Antelope Valley        0.812906      0.671954
# 4  2012      Bakersfield         0.77057      0.521361

# %%
math_yearly.to_csv(f"{path}/{file}_normalized.csv", index=False)
